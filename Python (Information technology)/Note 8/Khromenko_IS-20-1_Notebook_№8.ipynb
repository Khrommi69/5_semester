# %% [markdown]
# # Notebook №8. Information systems

# %% [markdown]
# by a student of the IS-20-1 group, Khromenko Danil.
# <br>

# %% [markdown]
# ## With environment for opening files

# %% [markdown]
# Last time we discussed working with files, but I didn't have time to tell you about an important construction
# with , which is often used to automatically close open files.
# Let's consider the application of this construction by example.

# %% [markdown]
# First, let's create a file that we will open. Let it be test_123.py . If you
# have a file with this name in your laptop folder that is very valuable to you, then replace
# the value of the filename variable with something else.

# %%
#file name - test_123.py
filename = 'test_123.py'

# %%
#open a file for recording
f = open(filename, 'w')
#write the "print('Hello, world!!!')" command to a file
f.write("print('Hello, world!!!')")
#close the file for writing
f.close()

# %% [markdown]
# The standard problem with files is that any open file must be closed.
# In the previous lecture I showed you this syntax:

# %%
#open the file and read it
open(filename).read()
# Out:
# "print('Hello, world!!!')"

# %% [markdown]
# This is a very short, but not very good syntax, because closing the file is left to
# the so-called garbage collector system, and it is not known exactly when the file will be closed.

# %% [markdown]
# *In the standard Python implementation, which is called CPython, garbage collector
# is designed in such a way that the file is closed immediately after executing this line,
# but other implementations may behave differently and in some situations
# problems may arise with such code.*

# %%
#It's better to do this
with open(filename) as f:
    print(f.read())
# Out:
# print('Hello, world!!!')

# %% [markdown]
# When entering the with construct, a line equivalent to f = open(filename) is executed. Then
# the indented lines are executed, and when the indentation ends,
# the file will be closed automatically. So these two lines are equivalent to:

# %%
#this code is completely similar to the previous one
f = open(filename)
print(f.read())
f.close()
# Out:
# print('Hello, world!!!')

# %%
#Here is another example
#open the file and close it after completing the with block
with open(filename) as f:
    #read information from a file
    print(f.read())
    #go back to the beginning of the file
    f.seek(0)
    #read information from a file
    print(f.read())
# Out:
# print('Hello, world!!!')
# print('Hello, world!!!')

# %% [markdown]
# Here we use the construction f.seek(0) to "rewind" the file to the beginning — in this case, repeated f.read() will again output its contents.
#
# Now let's try to do something with the file after the indentation.

# %%
with open(filename) as f:
    print(f.read())
    f.seek(0)
    print(f.read())
#attempt to read the file after closing it (with block)
#an error occurs because the file is closed (not open for reading)
print(f.read())
# Out:
# print('Hello, world!!!')
# print('Hello, world!!!')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13960\115696226.py in <module>
#       5 #attempt to read the file after closing it (with block)
#       6 #an error occurs because the file is closed (not open for reading)
# ----> 7 print(f.read())
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# As you can see, immediately after the end of the block (indented, as usual), the file is closed.
#
# And the with syntax has several advantages over the traditional approach. Firstly, you
# certainly won't forget to close the file, because you can forget to write f.close(), but you can't forget
# to remove the indentation. Secondly, even if you don't forget f.close(), you may not reach it
# because there was some mistake on the way.

# %% [markdown]
# ### A little bit about exceptions

# %% [markdown]
# In the code below, after the file has been opened, division by 0 occurs. Construction<br>
# <pre>
# try:
#     something
# except Name_of_some_error:
#     do_something_else
# </pre>
# allows, if an error of the Name_of_some_error type occurs, not to end
# the program with the words "Everything is gone! Error!", and immediately transfer control to the block
# do_something_else, which will do something. Interestingly, what is in the block
# do_something_else in the example below, the file was still open, which is bad. This
# can be compared to the situation: you put the kettle on the stove, but then you got an urgent
# call and you ran away, and the fire remained unquenched.

# %%
try:
    f = open(filename)
    print(f.read())
    #the error occurs here due to division by 0
    print(10/0)
    print('This is never been printed')
    f.close()
except ZeroDivisionError:
    print("Ups, I did it again!")
    f.seek(0)
    print(f.read())
# Out:
# print('Hello, world!!!')
# Ups, I did it again!
# print('Hello, world!!!')

# %% [markdown]
# And here the situation is like this: although we ran away on an urgent call, but the smart kettle immediately turned itself
# off. As you can see, when trying to read from a file in the except block, we get an error, and this
# is good, it means that the file has closed, despite the error.

# %%
#In this code block, if an error occurs, the file will be closed automatically due to the with block
try:
    with open(filename) as f:
        print(f.read())
        print(10/0)
        print('This is never been printed')
except ZeroDivisionError:
    print("Ups, I did it again!")
    #The error occurs here because the user is trying to get information from a closed file
    print(f.read())
# Out:
# print('Hello, world!!!')
# Ups, I did it again!
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13960\2531047331.py in <module>
#       4         print(f.read())
# ----> 5         print(10/0)
#       6         print('This is never been printed')
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13960\2531047331.py in <module>
#       8     print("Ups, I did it again!")
#       9     #The error occurs here because the user is trying to get information from a closed file
# ---> 10     print(f.read())
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## Appending to a file

# %% [markdown]
# We often need to do one thing with a file - either read or write. Sometimes we need
# to modify a file. Most often, this is done as follows: the file is first read into memory, then
# modified in memory and written "from scratch" to the same place as before. If we are talking about not
# very large files, then this method works fine.
#
# At the same time, sometimes we don't need to overwrite the file from scratch, but add some information to the
# end of the file. Most often, this has to be done to record logs in which some
# information about the operation of the program is stored (for example, the web server thus logs from which
# addresses it was accessed and which pages were requested). To add something to the end of the file,
# you need to open it with the modifier 'a' (from the word append) like this:

# %%
#writing information to the end of the file
with open(filename, 'a') as f:
    print("\n" + "print('Some new string')", file = f)

# %%
#Let's check that the old content remains in place
with open(filename) as f:
    print(f.read())
# Out:
# print('Hello, world!!!')
# print('Some new string')

# %% [markdown]
# ## Extracting data from web pages

# %% [markdown]
# ### Loading a web page: requests module

# %% [markdown]
# If the line below does not work for you, then do pip install requests or conda install
# requests on the command line (for example, in Anaconda Prompt).

# %%
import requests

# %% [markdown]
# The requests module allows you to access web pages. There are two common ways
# to access web pages: a get request and a post request (although there are actually many more types of http requests). A get request is when you send some information to the server in the address bar.
# For example, if you go to this address: https://www.google.ru/?q=sevsu+department+IS
# (https://www.google.ru/?q=sevsu+department+IS), then you are asking Google to search for "sevsu
# department of IS". a post request is when you need to enter information in some form,
# for example, enter a login password that will not be displayed in the browser's address bar.
#
# We will use get requests for now.

# %%
r = requests.get('http://www.sevsu.ru')

# %%
#To check that the page has loaded normally, there is a command
r.ok
# Out:
# True

# %% [markdown]
# The value True indicates that everything went fine.

# %%
#attempt to navigate to a non-existent page
q = requests.get('http://www.sevsu.ru/anyabsentdirectory')
print(q.ok)
# Out:
# False

# %% [markdown]
# We tried to navigate to a non-existent page and it didn't load. Let 's go back to the successful
# r query.

# %%
#Let's look at the html source of the page with the command
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="ru">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <title>Севастопольский государственный университет</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <link rel="apple-touch-icon" sizes="57x57" href="/local/templates/sevgu/static/ico/apple-icon-57x57.png">
#     <link rel="apple-touch-icon" sizes="60x60" href="/local/templates/sevgu/static/ico/apple-icon-60x60.png">
#     <link rel="apple-touch-icon" sizes="72x72" href="/local/templates/sevgu/static/ico/apple-icon-72x72.png">
#     <link rel="apple-touch-icon" sizes="76x76" href="/local/templates/sevgu/static/ico/apple-icon-76x76.png">
#     <link rel="apple-touch-icon" sizes="114x114" href="/local/templates/sevgu/static/ico/apple-icon-114x114.png">
#     <link rel="apple-touch-icon" sizes="120x120" href="/local/templates/sevgu/static/ico/apple-icon-120x120.png">
#     <link rel="apple-touch-icon" sizes="144x144" href="/local/templates/sevgu/static/ico/apple-icon-144x144.png">
#     <link rel="apple-touch-icon" sizes="152x152" href="/local/templates/sevgu/static/ico/apple-icon-152x152.png">
#     <link rel="apple-touch-icon" sizes="180x180" href="/local/templates/sevgu/static/ico/apple-icon-180x180.png">
#     <link rel="icon" type="image/png" sizes="192x192"  href="/local/templates/sevgu/static/ico/android-icon-192x192.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/local/templates/sevgu/static/ico/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="96x96" href="/local/templates/sevgu/static/ico/favicon-96x96.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/local/templates/sevgu/static/ico/favicon-16x16.png">
#     <link rel="manifest" href="/local/templates/sevgu/static/ico/manifest.json">
#     <meta name="msapplication-TileColor" content="#ffffff">
#     <meta name="msapplication-TileImage" content="/local/templates/sevgu/static/ico/ms-icon-144x144.png">
#     <meta name="theme-color" content="#ffffff">
#
#     <meta property="og:image" content="https://www.sevsu.ru/local/templates/sevgu/static/img/content/microdata-label.jpg">
#     <meta property="og:description" content="Севастопольский государственный университет (СевГУ) - один из крупнейших вузов юга России, ведущий научно-образовательный центр Крыма и Севастополя. В СевГУ входят 13 институтов, Морской колледж и лицей.">
#     <meta property="og:title" content="Севастопольский государственный университет">
#     <meta property="og:type" content="article"/>
#
#     <meta name="twitter:card" content="summary">
#     <meta name="twitter:creator" content="@sevsu_ru">
#     <meta name="twitter:site" content="@sevsu_ru">
#     <meta name="twitter:image" content="https://www.sevsu.ru/local/templates/sevgu/static/img/content/microdata-label.jpg">
#     <meta name="twitter:title" content="Севастопольский государственный университет">
#     <meta name="twitter:description" content="Севастопольский государственный университет (СевГУ) - один из крупнейших вузов юга России, ведущий научно-образовательный центр Крыма и Севастополя. В СевГУ входят 13 институтов, Морской колледж и лицей.">
#
#     <!-- This make sence for mobile browsers. It means, that content has been optimized for mobile browsers -->
#     <meta name="HandheldFriendly" content="true">
#
#     <!--[if (gt IE 9)|!(IE)]><!-->
#     <link href="/local/templates/sevgu/static/css/main.css?1669875585597765" rel="stylesheet" type="text/css">
#     <link href="/local/html/static/css/main-new.css?1669973886134616" rel="stylesheet" type="text/css">
#     <link href="/local/html/static/css/main-modern.css?16699738866731" type="text/css" rel="stylesheet" / >
#
#     <!--<![endif]-->
#     <link rel="image_src" href=""/>
#     <script>
#         (function (H) {
#             H.className = H.className.replace(/\bno-js\b/, 'js')
#         })(document.documentElement)
#     </script>
#     <script src="/local/templates/sevgu/js/jquery-3.4.1.min.js"></script>
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta name="robots" content="index, follow" />
# <meta name="keywords" content="факультеты, специальность, преподаватели" />
# <meta name="description" content="Севастопольский государственный университет (СевГУ) - один из крупнейших вузов юга России, ведущий научно-образовательный центр Крыма и Севастополя. В СевГУ входят 13 институтов, Морской колледж и лицей." />
# <link href="/local/templates/sevgu/components/bitrix/news.list/sevsu.slider.main.list/style.css?1658841692592" type="text/css"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/main_announce/style.css?1640799639150" type="text/css"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/main_promo/style.css?1640799639150" type="text/css"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/main_news_sevsunow/style.css?1640799639409" type="text/css"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/main_news/style.css?1640799639150" type="text/css"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/main_video/style.css?1640799639150" type="text/css"  rel="stylesheet" />
# <link href="/local/templates/sevgu/static/css/magnific-popup.css?16407996397348" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <link href="/local/templates/sevgu/static/css/file_icons.css?16407996391304" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/langs_mob/style.css?1656420912346" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/news.list/langs/style.css?1656404406339" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <link href="/local/templates/sevgu/components/bitrix/form.result.new/site_error/style.css?1657647976113" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <link href="/local/templates/sevgu/styles.css?16581455679064" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <link href="/local/templates/sevgu/template_styles.css?16698755853420" type="text/css"  data-template-style="true"  rel="stylesheet" />
# <script type="text/javascript">if(!window.BX)window.BX={};if(!window.BX.message)window.BX.message=function(mess){if(typeof mess==='object'){for(let i in mess) {BX.message[i]=mess[i];} return true;}};</script>
# <script type="text/javascript">(window.BX||top.BX).message({'JS_CORE_LOADING':'Загрузка...','JS_CORE_NO_DATA':'- Нет данных -','JS_CORE_WINDOW_CLOSE':'Закрыть','JS_CORE_WINDOW_EXPAND':'Развернуть','JS_CORE_WINDOW_NARROW':'Свернуть в окно','JS_CORE_WINDOW_SAVE':'Сохранить','JS_CORE_WINDOW_CANCEL':'Отменить','JS_CORE_WINDOW_CONTINUE':'Продолжить','JS_CORE_H':'ч','JS_CORE_M':'м','JS_CORE_S':'с','JSADM_AI_HIDE_EXTRA':'Скрыть лишние','JSADM_AI_ALL_NOTIF':'Показать все','JSADM_AUTH_REQ':'Требуется авторизация!','JS_CORE_WINDOW_AUTH':'Войти','JS_CORE_IMAGE_FULL':'Полный размер'});</script>
#
# <script type="text/javascript" src="/bitrix/js/main/core/core.js?1667232174488362"></script>
#
# <script>BX.setJSList(['/bitrix/js/main/core/core_ajax.js','/bitrix/js/main/core/core_promise.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/loadext/loadext.js','/bitrix/js/main/loadext/extension.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/includes/js/includes.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/ui/polyfill/closest/js/closest.js','/bitrix/js/main/polyfill/fill/main.polyfill.fill.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/core/core.js','/bitrix/js/main/polyfill/intersectionobserver/js/intersectionobserver.js','/bitrix/js/main/lazyload/dist/lazyload.bundle.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/parambag/dist/parambag.bundle.js']);
# BX.setCSSList(['/bitrix/js/main/lazyload/dist/lazyload.bundle.css','/bitrix/js/main/parambag/dist/parambag.bundle.css']);</script>
# <script type="text/javascript">(window.BX||top.BX).message({'LANGUAGE_ID':'ru','FORMAT_DATE':'DD.MM.YYYY','FORMAT_DATETIME':'DD.MM.YYYY HH:MI:SS','COOKIE_PREFIX':'BITRIX_SM','SERVER_TZ_OFFSET':'10800','UTF_MODE':'Y','SITE_ID':'s1','SITE_DIR':'/','USER_ID':'','SERVER_TIME':'1670686448','USER_TZ_OFFSET':'0','USER_TZ_AUTO':'Y','bitrix_sessid':'02bd3818b77cb5eb1e44a417711ec882'});</script>
#
#
# <script type="text/javascript" src="https://api-maps.yandex.ru/2.1/?lang=ru_RU&apikey=ffa4baec-9132-4256-a9d9-8389bd1b4a3f"></script>
#
#
# <script type="text/javascript" src="/local/templates/sevgu/js/vue.min.js?164079963993670"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/vue-the-mask.js?16407996394737"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/lodash.min.js?164079963973156"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/axios.min.js?164079963914355"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/jquery-3.5.1.min.js?1650615864206111"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/swiper.5.1.0.min.js?1650615864136195"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/jquery-filestyle.js?165061586414418"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/select2-4.0.13.min.js?165061586479212"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/lightbox-v2.11.2.js?165061586422394"></script>
# <script type="text/javascript" src="/bitrix/themes/ylab.likes/js/YlabLikesForm.js?16176199391603"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/jquery.magnific-popup.min.js?164079963920217"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/lightbox.js?16407996391081"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/validators0.7.7.min.js?16552831446883"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/vuelidate0.7.7.min.js?165528314413199"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/stacktable1.0.3.min.js?16553718563257"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/snowstorm-min.js?16699738869554"></script>
# <script type="text/javascript" src="/local/templates/sevgu/components/bitrix/menu/sgu_top_menu/script.js?16539146972438"></script>
# <script src="/local/node_modules/@sentry/browser/build/bundle.min.js" crossorigin="anonymous"></script><script>Sentry.init({ dsn: 'https://818dd69038ae45f7881a342b03bc6cc1@sentry.rarus-crimea.ru/48' });</script>
#
#
#
#     <script type="text/javascript">!function () {
#             var t = document.createElement("script");
#             t.type = "text/javascript", t.async = !0, t.src = 'https://vk.com/js/api/openapi.js?169', t.onload = function () {
#                 VK.Retargeting.Init("VK-RTRG-1464098-8DOms"), VK.Retargeting.Hit()
#             }, document.head.appendChild(t)
#         }();</script>
#     <noscript><img src="https://vk.com/rtrg?p=VK-RTRG-1464098-8DOms" style="position:fixed; left:-999px;" alt=""/>
#     </noscript>
#
#     <!-- Rating Mail.ru counter -->
#     <script type="text/javascript">
#         var _tmr = window._tmr || (window._tmr = []);
#         _tmr.push({id: "3249217", type: "pageView", start: (new Date()).getTime(), pid: "USER_ID"});
#         (function (d, w, id) {
#             if (d.getElementById(id)) return;
#             var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#             ts.src = "https://top-fwz1.mail.ru/js/code.js";
#             var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#             if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#         })(document, window, "topmailru-code");
#     </script><noscript><div>
#             <img src="https://top-fwz1.mail.ru/counter?id=3249217;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
#         </div></noscript>
#     <!-- //Rating Mail.ru counter -->
#
#     <!-- Yandex.Metrika counter --><script type="text/javascript"> (function (d, w, c) { (w[c] = w[c] || []).push(function() { try { w.yaCounter34823530 = new Ya.Metrika({ id:34823530, clickmap:true, trackLinks:true, accurateTrackBounce:true, webvisor:true }); } catch(e) { } }); var n = d.getElementsByTagName("script")[0], s = d.createElement("script"), f = function () { n.parentNode.insertBefore(s, n); }; s.type = "text/javascript"; s.async = true; s.src = "https://mc.yandex.ru/metrika/watch.js"; if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); } })(document, window, "yandex_metrika_callbacks"); </script>
#
# </head>
# <body>
#     <noscript>
#         <div>
#             <img src="https://mc.yandex.ru/watch/34823530" style="position:absolute; left:-9999px;" alt="" />
#         </div>
#     </noscript>
#
#
# <div class="container">
#     <div class="dev-notice">
#         <div class="dev-notice__text"></div>
#         <div class="dev-notice__links">
#             <div><a href="/admission/" target="_blank"
#                     title="Приемная комиссия"
#                     class="link link--blue">Приемная комиссия</a></div>
#             <div><a href="tel:+7 (8692) 222-911" title="Позвонить +7 (8692) 222-911" class="link link--black"><i class="dev-notice__icon dev-notice__icon--tel"></i>+7 (8692) 222-911</a></div>
#                         <div><a href="/cdn-cgi/l/email-protection#30404259555d7043554643451e4245" title="Написать priem@sevsu.ru" class="link link--black"><i class="dev-notice__icon dev-notice__icon--mail"></i><span class="__cf_email__" data-cfemail="ed9d9f848880ad9e889b9e98c39f98">[email&#160;protected]</span></a></div>
#         </div>
#     </div>
# </div>
#
# <div class="main"><div class="main-banner"><header class="header">
#     <div class="container">
#         <div class="d-flex header__wrap">
#             <a href="https://www.sevsu.ru" class="header__logo">
#                 <img src="/local/templates/sevgu/static/img/content/logo-footer.svg" alt="">
#             </a>
#
#             <div class="header__menu-wrap">
#
#
# <ul class="header__menu-top">
#     <li class="header__menu-top-li">
#         <a href="https://lk.sevsu.ru/user/sign-in/login" class="logout-icon" title="Личный кабинет">
#             <img class="select-sight__image" src="/local/html/icon-svg/menu-1.svg" alt="Личный кабинет">
#         </a>
#     </li>
#     <li class="header__menu-top-li">
#         <a href="/search/" class="faint-sight" title="Поиск">
#             <img class="select-sight__image" src="/local/html/icon-svg/menu-2.svg" alt="Поиск">
#         </a>
#     </li>
#     <li class="header__menu-top-li">
#         <a href="?special_version=Y" class="faint-sight bvi-open" title="Для слабовидящих">
#             <img class="select-sight__image" src="/local/html/icon-svg/ocular.svg" alt="Для слабовидящих">
#         </a>
#     </li>
#     <li class="header__menu-top-li">
#         <a href="#" class="select-language" title="Смена языка">
#     <img class="select-language__image" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" alt="Смена языка">
# </a>
# <ul class="icon-rus__list list-all mobile">
#         <li class="icon-rus__item">
#         <a href="https://www.sevsu.ru/admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" />
#             RU        </a>
#     </li>
#         <li class="icon-rus__item">
#         <a href="https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/cf5/lw5pf2vo13ir6mydthsjmclw9swcqkzo.svg" />
#             EN        </a>
#     </li>
#         <li class="icon-rus__item">
#         <a href="https://www.cn.sevsu.ru/admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/e2f/4bcxnbez3uq8s47lxyuwfpmdrdqyh3eu.svg" />
#             CN        </a>
#     </li>
#         <li class="icon-rus__item">
#         <a href="https://old.sevsu.ru/arab/admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/cf2/zup4zfdkt36au65lppgjoh2y0j48zd4m.svg" />
#             SY        </a>
#     </li>
#     </ul>    </li>
# </ul>
#
# <ul class="header__menu-main">
#             <li>
#             <a href="https://welcome.sevsu.ru/">
#                 <div class="icon header-enrollee"></div>
#                 АБИТУРИЕНТАМ            </a>
#         </li>
#             <li>
#             <a href="https://old.sevsu.ru/studentam/">
#                 <div class="icon header-training"></div>
#                 ОБУЧАЮЩИМСЯ            </a>
#         </li>
#             <li>
#             <a href="/uni/dap/service-dap">
#                 <div class="icon header-employee"></div>
#                 СОТРУДНИКАМ            </a>
#         </li>
#             <li>
#             <a href="/uni/career">
#                 <div class="icon header-graduate"></div>
#                 ВЫПУСКНИКАМ            </a>
#         </li>
#     </ul>
#
#
# <ul class="header__menu">
#
#
#
#         <li class="header__menu--item">
#
#             <a class="header__menu--link"
#                               href="/uni/">Университет</a>
#
#
#
#
#             <div class="level-1 grid-col-1">
#
#                 <ul class="header__menu-top">
#                     <li class="header__menu-top-li">
#                         <a href="https://lk.sevsu.ru/user/sign-in/login" class="logout-icon" title="Личный кабинет">
#                             <img class="select-sight__image" src="/local/html/icon-svg/menu-1.svg" alt="Личный кабинет">
#                         </a>
#                     </li>
#                     <li class="header__menu-top-li">
#                         <a href="/search/" class="faint-sight" title="Поиск">
#                             <img class="select-sight__image" src="/local/html/icon-svg/menu-2.svg" alt="Поиск">
#                         </a>
#                     </li>
#                     <li class="header__menu-top-li">
#                         <a href="?special_version=Y" class="faint-sight bvi-open" title="Для слабовидящих">
#                             <img class="select-sight__image" src="/local/html/icon-svg/ocular.svg" alt="Для слабовидящих">
#                         </a>
#                     </li>
#                     <li class="header__menu-top-li">
#                         <a href="#" class="select-language" title="Смена языка">
#     <img class="select-language__image" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" alt="Смена языка">
# </a>
# <ul class="icon-rus__list list-all mobile">
#         <li class="icon-rus__item">
#         <a href="https://www.sevsu.ru/admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" />
#             RU        </a>
#     </li>
#         <li class="icon-rus__item">
#         <a href="https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/cf5/lw5pf2vo13ir6mydthsjmclw9swcqkzo.svg" />
#             EN        </a>
#     </li>
#         <li class="icon-rus__item">
#         <a href="https://www.cn.sevsu.ru/admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/e2f/4bcxnbez3uq8s47lxyuwfpmdrdqyh3eu.svg" />
#             CN        </a>
#     </li>
#         <li class="icon-rus__item">
#         <a href="https://old.sevsu.ru/arab/admission/item/podat-dokumenty/"
#            rel="nofollow noopener" target="_self"
#             <img src="/upload/iblock/cf2/zup4zfdkt36au65lppgjoh2y0j48zd4m.svg" />
#             SY        </a>
#     </li>
#     </ul>                    </li>
#                 </ul>
#
#                     <div class="menu-container__return">
#                         <!--    Кнопка отвечающая за возврат в главное меню, название генерируется исходя из раздела, в котором находится пользователь -->
#                         <div class="menu-container__return-block">
#                             <a class="menu-container__return-link" href="#">
#                                 <img class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"
#                                      alt="Вернуться назад">
#                                 Университет                            </a>
#                         </div>
#
#                         <div class="li-icon">
#                             <a href="#" class="select-language" title="Смена языка">
#                                 <img class="select-language__image" src="/local/html/icon-svg/select-language.svg"
#                                      alt="Смена языка">
#                             </a>
#                             <a href="?special_version=Y" class="faint-sight" title="Для слабовидящих">
#                                 <img class="select-sight__image" src="/local/html/icon-svg/ocular.svg"
#                                      alt="Для слабовидящих">
#                             </a>
#                         </div>
#
#                     </div>
#
#
#                         <div class="menu-container_column">
#                             <h4 class="menu-container__title">
#                                                             </h4>
#                             <ul class="menu-container__list">
#
#
#
#                                                                             <li class="menu-container__item  ">
#
#                                             <a href="/uni/about/"
#                                                                                                class="menu-container__link "
#                                                title="Перейти в О СевГУ">
#                                                 О СевГУ                                                                                            </a>
#
#
#                                         </li>
#
#                                                                             <li class="menu-container__item  ">
#
#                                             <a href="/uni/rector/"
#                                                                                                class="menu-container__link "
#                                                title="Перейти в Страница ректора">
#                                                 Страница ректора                                                                                            </a>
#
#
#                                         </li>
#
#                                                                             <li class="menu-container__item  ">
#
#                                             <a href="/uni/nabsovet/"
#                                                                                                class="menu-container__link "
#                                                title="Перейти в Наблюдательный совет">
#                                                 Наблюдательный совет                                                                                            </a>
#
#
#                                         </li>
#
#                                                                             <li class="menu-container__item  menu-container__item-drop">
#
#                                             <a href="/uni/academic-board"
#                                                                                                class="menu-container__link menu-container__link--drop"
#                                                title="Перейти в Ученый совет">
#                                                 Ученый совет                                                                                                    <img class="anchor-link__icon"
#                                                          src="/local/html/static/img/content/education/arrow-right.svg"
#                                                          alt="Декоративная иконка">
#                                                                                             </a>
#
#
#                                                 <div class="level-2">
#                                                     <div class="menu-container_column menu-container_column-return">
#                                                         <h4 class="menu-container__title return-back">
#                                                             Вернуться назад
#                                                         </h4>
#                                                     </div>
#                                                     <div class="menu-container_column">
#                                                         <ul class="header__menu-top">
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="https://lk.sevsu.ru/user/sign-in/login" class="logout-icon" title="Личный кабинет">
#                                                                     <img class="select-sight__image" src="/local/html/icon-svg/menu-1.svg" alt="Личный кабинет">
#                                                                 </a>
#                                                             </li>
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="/search/" class="faint-sight" title="Поиск">
#                                                                     <img class="select-sight__image" src="/local/html/icon-svg/menu-2.svg" alt="Поиск">
#                                                                 </a>
#                                                             </li>
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="?special_version=Y" class="faint-sight bvi-open" title="Для слабовидящих">
#                                                                     <img class="select-sight__image" src="/local/html/icon-svg/ocular.svg" alt="Для слабовидящих">
#                                                                 </a>
#                                                             </li>
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="#" class="select-language" title="Смена языка">
#                                                                     <img class="select-language__image" src="/local/html/icon-svg/select-language.svg" alt="Смена языка">
#                                                                 </a>
#                                                                 <ul class="icon-rus__list list-all">
#                                                                     <li class="icon-rus__item">
#                                                                         <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>
#                                                                     </li>
#                                                                     <li class="icon-rus__item">
#                                                                         <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>
#                                                                     </li>
#                                                                     <li class="icon-rus__item">
#                                                                         <a href="/">RU</a>
#                                                                     </li>
#                                                                 </ul>
#                                                             </li>
#                                                         </ul>
#                                                         <h4 class="menu-container__title menu-container__title--desctop">
#                                                             Ученый совет                                                        </h4>
#                                                         <div class="menu-container__title--mobile">
#                                                             <a class="return-link--level-2" href="#">
#                                                                 <img class="menu-container__image"
#                                                                      src="/local/html/icon-svg/arrow-left.svg"
#                                                                      alt="Вернуться назад">
#                                                                 Ученый совет                                                            </a>
#                                                             <div class="li-icon">
#                                                                 <a href="#" class="select-language" title="Смена языка">
#                                                                     <img class="select-language__image"
#                                                                          src="/local/html/icon-svg/select-language.svg"
#                                                                          alt="Смена языка">
#                                                                 </a>
#                                                                 <a href="?special_version=Y" class="faint-sight"
#                                                                    title="Для слабовидящих">
#                                                                     <img class="select-sight__image"
#                                                                          src="/local/html/icon-svg/ocular.svg"
#                                                                          alt="Для слабовидящих">
#                                                                 </a>
#                                                             </div>
#                                                         </div>
#                                                         <ul class="menu-container__list">
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board//"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Состав ученого совета Университета">
#                                                                         Состав ученого совета Университета                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/ab-reg"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Положение об учёном совете">
#                                                                         Положение об учёном совете                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/ab-rules"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Регламент работы ученого совета">
#                                                                         Регламент работы ученого совета                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/plan-uch-sovet"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="План работы учёного совета">
#                                                                         План работы учёного совета                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/materials"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Материалы к ученому совету">
#                                                                         Материалы к ученому совету                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/docs"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Локальные нормативные документы">
#                                                                         Локальные нормативные документы                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/comission"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Комиссия ученого совета">
#                                                                         Комиссия ученого совета                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/uni"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Учёные советы институтов">
#                                                                         Учёные советы институтов                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/rus"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Решения ученого совета">
#                                                                         Решения ученого совета                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/nagrad"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Наградные материалы">
#                                                                         Наградные материалы                                                                    </a>
#                                                                 </li>
#
#
#                                                                 <li class="menu-container__item">
#                                                                     <a href="/uni/academic-board/poryadok-prisvoeniya-uchenykh-zvaniy"
#                                                                                                                                                class="menu-container__link"
#                                                                        style=""
#                                                                        title="Порядок присвоения ученых званий">
#                                                                         Порядок присвоения ученых званий                                                                    </a>
#                                                                 </li>
#
#                                                                                                                     </ul>
#                                                     </div>
#                                                 </div>
#
#
#                                         </li>
#
#                                                                             <li class="menu-container__item  menu-container__item-drop">
#
#                                             <a href="/uni/programma-razvitiya"
#                                                                                                class="menu-container__link menu-container__link--drop"
#                                                title="Перейти в Программа развития">
#                                                 Программа развития                                                                                                    <img class="anchor-link__icon"
#                                                          src="/local/html/static/img/content/education/arrow-right.svg"
#                                                          alt="Декоративная иконка">
#                                                                                             </a>
#
#
#                                                 <div class="level-2">
#                                                     <div class="menu-container_column menu-container_column-return">
#                                                         <h4 class="menu-container__title return-back">
#                                                             Вернуться назад
#                                                         </h4>
#                                                     </div>
#                                                     <div class="menu-container_column">
#                                                         <ul class="header__menu-top">
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="https://lk.sevsu.ru/user/sign-in/login" class="logout-icon" title="Личный кабинет">
#                                                                     <img class="select-sight__image" src="/local/html/icon-svg/menu-1.svg" alt="Личный кабинет">
#                                                                 </a>
#                                                             </li>
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="/search/" class="faint-sight" title="Поиск">
#                                                                     <img class="select-sight__image" src="/local/html/icon-svg/menu-2.svg" alt="Поиск">
#                                                                 </a>
#                                                             </li>
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="?special_version=Y" class="faint-sight bvi-open" title="Для слабовидящих">
#                                                                     <img class="select-sight__image" src="/local/html/icon-svg/ocular.svg" alt="Для слабовидящих">
#                                                                 </a>
#                                                             </li>
#                                                             <li class="header__menu-top-li">
#                                                                 <a href="#" class="select-language" title="Смена языка">
#                                                                     <img class="select-language__image" src="/local/html/icon-svg/select-language.svg" alt="Смена языка">
#                                                                 </a>
#                                                                 <ul class="icon-rus__list list-all">
#                                                                     <li class="icon-rus__item">
#                                                                         <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>
#                                                                     </li>
#                                                                     <li class="icon-rus__item">
#                                                                         <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>
#                                                                     </li>
#                                                                     <li class="icon-rus__item">
#                                                                         <a href="/">RU</a>
#                                                                     </li>
#                                                                 </ul>
#                                                             </li>
#                                                         </ul>
#                                                         <h4 class="menu-container__title menu-container__title--desctop">
#                                                             Программа развития                                                        </h4>
#                                                         <div class="menu-container__title--mobile">
#                                                             <a class="return-link--level-2" href="#">
#                                                                 <img class="menu-container__image"
#                                                                      src="/local/html/icon-svg/arrow-left.svg"
#                                                                      alt="Вернуться назад">
#                                                                 Программа развития                                                            </a>
#                                                             <div class="li-icon">
#                                                                 <a href="#" class="select-language" title="Смена языка">
#                                                                     <img class="select-language__image"
#                                                                          src="/local/html/icon-svg/select-language.svg"
#                                                                          alt="Смена языка">
#                                                                 </a>
#                                                                 <a href="?special_version=Y" class="faint-sight"
#                                                                    title="Для слабовидящих">
#                                                                     <img class="select-sight__image"
#                                                                          src="/local/html/icon-svg/ocular.svg"
#                                                                          alt="Для слабовидящих">
# ...
#                                     <img src="/upload/iblock/e6b/e6b9dffa305b5ae30a208c02c5360d90.png"
#                                          alt="Государственный университет управления">
#                                 </div>
#                             </a>
#                         </div>
#
#
#                         <div class="swiper-slide">
#                             <a target="_blank" href="https://volsu.ru/">
#                                 <div class=" main-partners__image">
#                                     <img src="/upload/iblock/08a/08a7d735d3c1d79493edadd2a464aa14.png"
#                                          alt="Волгоградский государственный университет">
#                                 </div>
#                             </a>
#                         </div>
#
#
#                         <div class="swiper-slide">
#                             <a target="_blank" href="https://bashedu.ru/ru">
#                                 <div class=" main-partners__image">
#                                     <img src="/upload/iblock/c0c/c0c5a8e07360af7f7efa4a39c9065532.png"
#                                          alt="Башкирский государственный университет">
#                                 </div>
#                             </a>
#                         </div>
#
#
#                         <div class="swiper-slide">
#                             <a target="_blank" href="http://mpgu.su/">
#                                 <div class=" main-partners__image">
#                                     <img src="/upload/iblock/001/001c4e3d96a6223a95f5cb710ebef3d9.png"
#                                          alt="Московский педагогический государственный университет">
#                                 </div>
#                             </a>
#                         </div>
#
#
#                         <div class="swiper-slide">
#                             <a target="_blank" href="http://www.sevmash.ru/">
#                                 <div class=" main-partners__image">
#                                     <img src="/upload/iblock/b37/b37efa70d8cbfbf8b873917fda53bcc5.png"
#                                          alt="ОАО ПО &quot;Севмаш&quot;">
#                                 </div>
#                             </a>
#                         </div>
#
#
#
#                 </div>
#             </div>
#
#             <div class="swiper-button-next main-partners-next"></div>
#             <div class="swiper-button-prev main-partners-prev"></div>
#         </div>
#     </div>
# </div>
#
#
#
# </div>
#
#
# <div id="topNubex" class="btn-top"><img src="/local/html/static/img/minified-svg/aside-arrow.svg" alt="Кнопка наверх"></div>
#
# <div class="modal fade modal__found-error" id="modal__found-error" tabindex="-1" aria-hidden="true">
#     <div class="modal-dialog modal-dialog-centered">
#         <form id="errorForm">
#             <input type="hidden" name="web_form_apply" value="Y">
#             <input type="hidden" name="WEB_FORM_ID" value="65">
#             <input type="hidden" name="sessid" value="02bd3818b77cb5eb1e44a417711ec882">
#             <input type="hidden" name="form_text_538" value="https://www.sevsu.ru/">
#
#             <div class="modal-content modal__found-error-content">
#                 <div class="modal__icon"></div>
#                 <div class="modal__header">
#                     <div class="modal__header-start">
#                         <span class="modal__header-title">Нашли ошибку?</span>
#                         <span class="modal__header-text">Опишите проблему, которую Вы нашли на странице</span>
#                     </div>
#                     <div class="modal__header-done">
#                         <span class="modal__header-title">Спасибо!</span>
#                         <span class="modal__header-text">Ваше сообщение отправлено и вскоре будет рассмотрено</span>
#                     </div>
#                 </div>
#                 <div class="modal__body">
#                     <div class="news-offer__form-group" :class="{ 'has-error': $v.errorText.$error }">
#                     <textarea name="form_textarea_539" id="errorText"  class="modal__body-textarea form-control"
#                           v-model="errorText"
#                           placeholder="Введите описание ошибки"></textarea>
#                     <div class="form-group__error">Обязательное поле!</div>
#                     </div>
#
#                                             <div class="news-offer__form-group">
#                             <input type="text" class="form-control" name="captcha_word" placeholder="введите символы с картинки">
#                             <input type="hidden" name="captcha_sid" value="099a46ed5af847e3928007b5516714b5">
#                             <input type="hidden" name="captcha_sid" value="099a46ed5af847e3928007b5516714b5" /><img src="/bitrix/tools/captcha.php?captcha_sid=099a46ed5af847e3928007b5516714b5" width="180" height="40" />                        </div>
#
#                     <div v-if="responseError" class="form-group__error">{{responseError}}</div>
#
#                 </div>
#                 <div class="modal__buttons">
#                     <div class="modal__buttons-start">
#                         <button class="btn btn-blue-bg" @click.prevent="onSubmit">Отправить</button>
#                         <button class="btn btn-blue" @click.prevent data-bs-dismiss="modal" data-dismiss="modal">Отмена</button>
#                     </div>
#                     <div class="modal__buttons-done">
#                         <button class="btn btn-blue-bg" @click.prevent data-bs-dismiss="modal" data-dismiss="modal">Готово</button>
#                     </div>
#                 </div>
#             </div>
#         </form>
#     </div>
# </div>
#
# <script defer>
#     var {required} = window.validators;
#
#     Vue.use(window.vuelidate.default)
#
#     var errorForm = new Vue({
#         el: '#errorForm',
#         data: {
#             errorText: '',
#             responseError: '',
#         },
#         validations: {
#             errorText: {
#                 required
#             },
#         },
#         methods: {
#             onSubmit() {
#
#                 this.$v.$reset()
#                 this.$v.$touch()
#
#                 if (!this.$v.$invalid) {
#
#                     const form = $('#errorForm')[0];
#                     let formData = new FormData(form),
#                         that     = this;
#
#                     axios({
#                             headers         : {'X-Requested-With': 'XMLHttpRequest'},
#                             url             : '/api/site-error/',
#                             method          : 'post',
#                             data            : formData,
#                         }
#                     ).then(function (response) {
#                         if (!response.data.result && response.data.error) {
#                             that.responseError = response.data.error;
#                         } else {
#                             $('#errorForm .modal__found-error-content').addClass('modal__found-error--done');
#                             //document.location.href = '/novosti/';
#                             errorForm.errorText = '';
#                             errorForm.$v.$reset();
#                         }
#                     }).catch(function (error) {
#                         //
#                     }).then(function () {
#                         return false;
#                     });
#                 }
#             }
#         }
#     })
# </script>
# <div class="modal fade modal__found-error" id="modal__subscribe-done" tabindex="-1" aria-hidden="true">
#     <div class="modal-dialog modal-dialog-centered">
#         <div class="modal-content modal__found-error-content modal__found-error--done">
#             <div class="modal__icon"></div>
#             <div class="modal__header">
#                 <div class="modal__header-done">
#                     <span class="modal__header-title">Вы подписались!</span>
#                     <span class="modal__header-text">Вам на почту придет письмо о подтверждении подписки</span>
#                 </div>
#             </div>
#             <div class="modal__buttons">
#                 <div class="modal__buttons-done">
#                     <button class="btn btn-blue-bg" data-bs-dismiss="modal" data-dismiss="modal">Понятно</button>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
#
# <footer class="footer">
#     <div class="footer__wave">
#             <img src="/local/templates/sevgu/static/img/content/wave.svg" alt="">
#     </div>
#
#     <div class="container">
#         <div class="row footer__wrap">
#             <div class="footer__col">
#                 <h4>АБИТУРИЕНТ</h4>
#
# <ul class="footer__list">
#             <li>
#             <a href="/univers/">
#                 Институты            </a>
#         </li>
#             <li>
#             <a href="/specialnosti/">
#                 Направления подготовки            </a>
#         </li>
#             <li>
#             <a href="/uni/omo/ppig/">
#                 Иностранным гражданам            </a>
#         </li>
#             <li>
#             <a href="/infrastruktura/">
#                 Вне учебы            </a>
#         </li>
#             <li>
#             <a href="/sveden/">
#                 Сведения об образовательной организации            </a>
#         </li>
#     </ul>
# <!--                -->            </div>
#
#             <div class="footer__col">
#                 <div class="row">
#                     <div class="col-6">
#                         <h4>ПОЛЕЗНОЕ</h4>
#
# <ul class="footer__list">
#             <li>
#             <a href="https://welcome.sevsu.ru/" >
#                 Абитуриентам            </a>
#         </li>
#             <li>
#             <a href="/univers/kursy/pod-kursy/" >
#                 Подготовка к ЕГЭ            </a>
#         </li>
#             <li>
#             <a href="/admission/item/85-pravila-priema/" >
#                 Правила приема            </a>
#         </li>
#             <li>
#             <a href="#" data-bs-toggle="modal" data-bs-target="#modal__found-error">
#                 Сообщить об ошибке на странице            </a>
#         </li>
#     </ul>
#                     </div>
#                     <div class="col-6">
#                         <h4>СЕРВИСЫ</h4>
#
# <ul class="footer__list">
#             <li>
#             <a href="/kontakty/" >
#                 Контакты            </a>
#         </li>
#             <li>
#             <a href="https://old.sevsu.ru/activnost/svyaz/" >
#                 Сообщить о проблеме            </a>
#         </li>
#     </ul>
#                     </div>
#                 </div>
#             </div>
#
#             <div class="footer__col2">
#                 <div class="row">
#                     <div class="footer__logo-info">
#                         <a href="/" class="footer__logo">
#                             <img src="/local/templates/sevgu/static/img/content/logo-footer.svg" alt="">
#                         </a>
#
#                         <div class="footer__info d-none">
#                             <a href="?special_version=Y" class="footer__version bvi-open">
#                                 <div class="icon icon-version-white"></div>
#                                 Версия для слабовидящих                            </a>
#
#                             <p>Использование новостных материалов сайта                                <br>возможно только при наличии активной ссылки</p>
# <!--                            <p>Нашли ошибку?
#                                 <br>Выделите ее и нажмите CTRL+L</p>-->
#                         </div>
#
#
# <ul class="footer__soc">
#             <li>
#             <a target="_blank" href="https://vk.com/sevsu/" class="footer__soc-icon footer-vk"></a>
#         </li>
#             <li>
#             <a target="_blank" href="https://www.youtube.com/channel/UC1rFaFbJ4pDQgnrolyDfq0g/" class="footer__soc-icon footer-youtube"></a>
#         </li>
#             <li>
#             <a target="_blank" href="https://www.t.me/sevsu_live/" class="footer__soc-icon footer-telegram"></a>
#         </li>
#             <li>
#             <a target="_blank" href="https://ok.ru/group/61479744110674" class="footer__soc-icon footer-ok"></a>
#         </li>
#             <li>
#             <a target="_blank" href="https://rutube.ru/channel/25013780/" class="footer__soc-icon footer-rutube"></a>
#         </li>
#             <li>
#             <a target="_blank" href="https://edu.gov.ru/" class="footer__soc-icon footer-mpr"></a>
#         </li>
#             <li>
#             <a target="_blank" href="https://www.minobrnauki.gov.ru/" class="footer__soc-icon footer-mnor"></a>
#         </li>
#     </ul>
#                     </div>
#
#                     <div class="footer__info-wrapper">
#                         <div class="footer__info">
#                             <a href="?special_version=Y" class="footer__version bvi-open">
#                                 <div class="icon icon-version-white"></div>
#                                 Версия для слабовидящих                            </a>
#
#                             <p>Использование новостных материалов сайта                                <br>возможно только при наличии активной ссылки</p>
# <!--                            <p>Нашли ошибку?
#                                 <br>Выделите ее и нажмите CTRL+L</p>-->
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="footer__col footer__text">
#                 Сетевое издание «Севастопольский государственный университет». Учредитель: Федеральное государственное автономное образовательное учреждение высшего образования «Севастопольский государственный университет» (ОГРН 1149204039181). Свидетельство о регистрации СМИ ЭЛ № ФС77-78652 от 30 июля 2020 г. Выдано Федеральной службой по надзору в сфере связи, информационных технологий и массовых коммуникаций.                <br><br>
#                 Главный редактор: Ковалевский А. А. Адрес электронной почты редакции: <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="ed9d9f889e9ead9e889b9e98c3">[email&#160;protected]</a> ru, телефон редакции: +7(8692)435-210. Все права на любые материалы, опубликованные на сайте, защищены в соответствии с российским и международным законодательством об интеллектуальной собственности. Любое использование текстовых, фото-, аудио- и видеоматериалов, цитирование возможно только при условии гиперссылки на sevsu. ru.            </div>
#         </div>
#
#         <div class="footer__copy">Все права защищены © «Севастопольский государственный университет», 2022. 0+</div>
#     </div>
# </footer>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script>
#     (function (w, d, u) {
#         var s = d.createElement('script');
#         s.async = true;
#         s.src = u + '?' + (Date.now() / 60000 | 0);
#         var h = d.getElementsByTagName('script')[0];
#         h.parentNode.insertBefore(s, h);
#     })(window, document, 'https://org.sevsu.ru/upload/crm/site_button/loader_4_wex7a1.js');
# </script>
# <script type="text/javascript" src="/local/templates/sevgu/static/js/main.js?165942762215278"></script>
# <script type="text/javascript" src="/local/html/static/js/main-new.js?165762371110382"></script>
# <script type="text/javascript" src="/local/html/static/js/main-modern.js?166997562815116"></script>
# <script type="text/javascript" src="/local/templates/sevgu/script.js?16530352773051"></script>
# <script type="text/javascript" src="/local/templates/sevgu/components/bitrix/menu/sgu_top_menu/script.js?16539146972438"></script>
# <script type="text/javascript" src="/local/html/static/js/listeners.js?1655466609332"></script>
# <script type="text/javascript" src="/local/templates/sevgu/js/bootstrap.bundle.min.js?165588796778743"></script>
# </body>
# </html>

# %% [markdown]
# ### A little bit about HTML

# %% [markdown]
# What you see above is an HTML page. HTML (HyperText Markup Language) is such
# a markup language, which is a special case of the SGML standard. Another special case of SGML is
# XML, which we will meet again.
#
# Let's write a simple HTML page. It is most convenient to do this in any editor. But I'll write it to a file via my laptop.

# %%
#creating a string containing an html page
my_html = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset = "UTF-8">
    <title>Title</title>
</head>
<body>
<h1>Hello</h1>
<p>I'm a paragraph.</p>
<hr>
<ol>
    <li>One</li>
    <li>Two</li>
</ol>

</body>
</html>
'''

# %%
#write our string to an html file
with open('my.html', 'w') as f:
    f.write(my_html)

# %% [markdown]
# Open it my.html browser and you will see a simple web page. It can be seen that HTML is divided into special fragments, which are called tags. In the text above there are tags: &lt;html&gt;, &lt;head&gt;, &lt;title&gt;, etc. Each tag marks some piece of the web page. The &lt;title&gt; tag is the page title. The &lt;ol&gt; tag marks an ordered list. The &lt;li&gt; tag corresponds to the list item. The &lt;p&gt; tag is a paragraph. All the listed tags are paired: they mark some fragment of text (possibly containing other tags), placing it between the corresponding opening and the closing tag (for example, &lt;li&gt; is the opening tag, and &lt;/li&gt; is the closing tag; everything in between is a list item). The exception here is the &lt;hr&gt; tag, which draws a horizontal line (it works without &lt;/hr&gt;).
#
# In fact, an HTML page is a set of nested tags. We can say that this is a tree with a root in the &lt;html&gt; tag . Each tag has descendants - those tags that are directly nested in it. For example, the &lt;body&gt; tag will have &lt;h1&gt;, &lt;p&gt;, &lt;hr&gt;, &lt;ol&gt; descendants. It turns out such a kind of family tree.
#
# HTML interests us in order to extract information from such a tree. One of the most popular objects for storing information are tables, so let's insert a small table into our file: it is indicated by the &lt;table&gt; tag, each row of the table is marked with the &lt;tr&gt; tag inside &lt;table&gt;, and each cell is marked with the &lt;td&gt; tag inside &lt;tr&gt;.

# %%
#creating a string containing an html page
my_html = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset = "UTF-8">
    <title>Title</title>
    <style type='text/css;'>
        table {
        border-collapse: collapse;
    }
    table, th, td {
        border: 1px solid black;
    }
    </style>
</head>
<body>
<h1>Hello</h1>
<p>I'm a paragraph.</p>
<hr>
<ol>
    <li>One</li>
    <li>Two</li>
</ol>
<table>
    <tr>
        <td>
            Cell 1
        </td>
        <td>
            Cell 2
        </td>
    </tr>
    <tr>
        <td>
            Cell 3
        </td>
        <td>
            Cell 4
        </td>
    </tr>
</table>
</body>
</html>
'''
#write our string to an html file
with open('my.html', 'w') as f:
 f.write(my_html)

# %% [markdown]
# Let's assume that it lies somewhere on a remote site. Let's download it using requests and
# try to extract some information.

# %%
r = requests.get('http://math-info.hse.ru/f/2015-16/all-py/my.html')

# %% [markdown]
# ### BeautifulSoup

# %% [markdown]
# There are many packages for processing web pages. The problem with HTML is that most browsers behave "forgiving", and therefore there are a lot of poorly written (not according to the HTML standard) HTML pages on the web. However, processing even not quite correct HTML code is not so difficult
# if you have the right tools at hand.
#
# We will use the *Beautiful Soup 4* package. It is included in the standard Anaconda package, but
# if you use another Python distribution, you may have to install it manually
# using pip install beautifulsoup4.
#
# *A package called BeautifulSoup is most likely not what you need. This is the third
# version (Beautiful Soup 3), and we will use the fourth. So we need a package
# beautifulsoup4 . To make it really fun, when importing, you need to specify a different
# package name — bs4 , and import a function called BeautifulSoup . In
# general, it's easy to get confused at first, but these difficulties need to be overcome once, and
# then it will be easier.*

# %%
#importing Beautiful Soup
from bs4 import BeautifulSoup

# %% [markdown]
# To use *BeautifulSoup*, you need to pass the text of the web page (as
# a single line) to the *BeautifulSoup* function. In order for him not to swear, I also manually specify the name of the parser (the
# program that just processes HTML) — for compatibility, I use
# *html.parser* (it is included in the Python package and does not require installation), but you can also try
# using *lxml* if you have it installed.

# %%
#using BeautifulSoup
page = BeautifulSoup(r.text, 'html.parser')

# %%
#What now lies in the page variable? Let's take a look.
page
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Title</title>
# <style type="text/css;">
#         table {
#         border-collapse: collapse;
#     }
#
#     table, th, td {
#         border: 1px solid black;
#     }
#     </style>
# </head>
# <body>
# <h1>Hello</h1>
# <p>I'm a paragraph.</p>
# <hr/>
# <ol>
# <li>One</li>
# <li>Two</li>
# </ol>
# <table>
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>
# </table>
# </body>
# </html>

# %% [markdown]
# We see that the page object is very similar to a string, but, in fact, it is not just a string.
# You can make requests to the page.

# %%
#request to page: see what's inside the html tag
page.html
# Out:
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Title</title>
# <style type="text/css;">
#         table {
#         border-collapse: collapse;
#     }
#
#     table, th, td {
#         border: 1px solid black;
#     }
#     </style>
# </head>
# <body>
# <h1>Hello</h1>
# <p>I'm a paragraph.</p>
# <hr/>
# <ol>
# <li>One</li>
# <li>Two</li>
# </ol>
# <table>
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>
# </table>
# </body>
# </html>

# %% [markdown]
# We see what is inside the &lt;html&gt; tag (this is almost the entire page, but the very first line
# was "cut off"). You can go deeper and look at the contents of &lt;head&gt;.

# %%
#request to page: see what's inside the head tag
page.html.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Title</title>
# <style type="text/css;">
#         table {
#         border-collapse: collapse;
#     }
#
#     table, th, td {
#         border: 1px solid black;
#     }
#     </style>
# </head>

# %% [markdown]
# Now we only see what's inside the &lt;head&gt; tag . We can go even deeper and get what is inside the &lt;title&gt; tag, which in turn is inside the &lt;head&gt; tag (they say that &lt;title&gt; is a descendant of &lt;head&gt;:

# %%
#request to page: see what's inside the title tag
page.html.head.title
# Out:
# <title>Title</title>

# %% [markdown]
# However, it would be possible not to write in such detail — since there is only one tag in the document &lt;title&gt;, we could not specify that it is inside &lt;head&gt;, which is inside &lt;html&gt;.

# %%
page.head.title
# Out:
# <title>Title</title>

# %%
page.title
# Out:
# <title>Title</title>

# %%
#One of the descendants of <body> is <table>. You can get it like this:
page.body.table
# Out:
# <table>
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>
# </table>

# %% [markdown]
# Let's say I need to get multiple items with the same tag, for example, all rows
# &lt;tr&gt;. The following syntax is used for this:

# %%
#get multiple items with the same tag, for example, all rows <tr>
rows = page.body.table.findAll('tr')
rows
# Out:
# [<tr>
#  <td>
#              Cell 1
#          </td>
#  <td>
#              Cell 2
#          </td>
#  </tr>,
#  <tr>
#  <td>
#              Cell 3
#          </td>
#  <td>
#              Cell 4
#          </td>
#  </tr>]

# %%
#number of rows in 'rows'
len(rows)
# Out:
# 2

# %% [markdown]
# We see that this is a list of two elements. So you can cycle through it.

# %%
#output lines using a loop
for i, row in enumerate(rows, 1):
    print(i)
    print(row)
# Out:
# 1
# <tr>
# <td>
#             Cell 1
#         </td>
# <td>
#             Cell 2
#         </td>
# </tr>
# 2
# <tr>
# <td>
#             Cell 3
#         </td>
# <td>
#             Cell 4
#         </td>
# </tr>

# %% [markdown]
# We have 2 lines and each of them is the same BeautifulSoup object as all
# the previous ones. So you can apply the construction to them row.td.

# %%
#application of the "row.td" construction
for i, row in enumerate(rows):
    print(i)
    print(row.td)
# Out:
# 0
# <td>
#             Cell 1
#         </td>
# 1
# <td>
#             Cell 3
#         </td>

# %% [markdown]
# We see that if there are several &lt;td&gt; tags inside the &lt;row&gt; tag, then row.td will take the first of them.
# So we got the first column. But we are not interested in the &lt;td&gt; tag itself, but in the string that
# lies there. It can be printed like this.

# %%
#application of the "row.td.strong" construction
for i, row in enumerate(rows):
    print(i)
    print(row.td.string)
# Out:
# 0
#
#             Cell 1
#
# 1
#
#             Cell 3

# %% [markdown]
# It can be seen that there are unnecessary spaces before the line. Delete them with the strip command.

# %%
#application of the "row.td.string.strip()" construction
for i, row in enumerate(rows):
    print(i)
    print(row.td.string.strip())
# Out:
# 0
# Cell 1
# 1
# Cell 3

# %%
#Let's load the table as a list of lists
table = []
for i, row in enumerate(rows):
    table.append([])
    for cell in row.findAll('td'):
        table[-1].append(cell.string.strip())
print(table)
# Out:
# [['Cell 1', 'Cell 2'], ['Cell 3', 'Cell 4']]

# %%
#Here is the same thing, but shorter with the help of list comprehensions:
table = []
for row in rows:
    table.append([cell.string.strip() for cell in row.findAll('td')])
print(table)
# Out:
# [['Cell 1', 'Cell 2'], ['Cell 3', 'Cell 4']]

# %%
#Or even shorter (but more intricate):
table = [[cell.string.strip() for cell in row.findAll('td')]
    for row in rows]
print(table)
# Out:
# [['Cell 1', 'Cell 2'], ['Cell 3', 'Cell 4']]

# %% [markdown]
# Note that instead of some_beautiful_soup_object.findAll('sometag'), you can write shorter
# some_beautiful_soup_object('sometag'). So you can write even shorter.

# %%
#even shorter
table = [[cell.string.strip() for cell in row('td')]
    for row in rows]
print(table)
# Out:
# [['Cell 1', 'Cell 2'], ['Cell 3', 'Cell 4']]

# %% [markdown]
# Tags, in addition to the name, have other properties — for example, in the line &lt;html lang="en"&gt; we see the lang property of the &lt;html&gt; tag, which has the value "en". Another important example of a tag with
# properties is the &lt;a&gt; tag, which creates a link. It has a href property that stores the actual link.
#
# Now imagine that we want to make a robot that will walk on web pages, and
# go from one page to another by links. Then we are faced with the task of extracting all hyperlinks from the page. To do this, you need to find all the &lt;a&gt; tags on the page, and take
# the &lt;href&gt; parameter from all of them. To begin with, let's show how to get an object property, for example, lang from html .
# This is done as if our object is a dictionary, and we take its value by key.

# %%
#request to page: see what's inside the html tag, in the property 'lang'
page.html['lang']
# Out:
# 'en'

# %%
#If we request a property that the tag does not have, then we will get a KeyError, as with the dictionary
#ERROR: because there is an attempt to request a property that the tag does not have
page.html['strange']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13960\882293421.py in <module>
#       1 #If we request a property that the tag does not have, then we will get a KeyError, as with the dictionary
#       2 #ERROR: because there is an attempt to request a property that the tag does not have
# ----> 3 page.html['strange']
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1517         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518         and throws an exception if it's not there."""
# -> 1519         return self.attrs[key]
#    1520
#    1521     def __iter__(self):
#
# KeyError: 'strange'

# %% [markdown]
# Just like the dictionary, there is a get() method that returns nothing if there is no such property. Or returns the default value defined by us.

# %%
#using the get() method to check for the presence of a property
page.html.get('strange')

# %%
#using the get() method to check for the presence of a property
page.html.get('strange', 'no-such-tag')
# Out:
# 'no-such-tag'

# %%
#Now we will extract all the links from some site
r = requests.get('http://www.sevsu.ru')
page = BeautifulSoup(r.text, 'html.parser')

# %%
#Here are all the links on our page
page('a')
# Out:
# [<a class="link link--blue" href="/admission/" target="_blank" title="Приемная комиссия">Приемная комиссия</a>,
#  <a class="link link--black" href="tel:+7 (8692) 222-911" title="Позвонить +7 (8692) 222-911"><i class="dev-notice__icon dev-notice__icon--tel"></i>+7 (8692) 222-911</a>,
#  <a class="link link--black" href="/cdn-cgi/l/email-protection#a3d3d1cac6cee3d0c6d5d0d68dd1d6" title="Написать priem@sevsu.ru"><i class="dev-notice__icon dev-notice__icon--mail"></i><span class="__cf_email__" data-cfemail="d0a0a2b9b5bd90a3b5a6a3a5fea2a5">[email protected]</span></a>,
#  <a class="header__logo" href="https://www.sevsu.ru">
#  <img alt="" src="/local/templates/sevgu/static/img/content/logo-footer.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg"/>
#  </a>,
#  <a <img="" href="https://www.sevsu.ru/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" target="_self"></a>,
#  <a <img="" href="https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/cf5/lw5pf2vo13ir6mydthsjmclw9swcqkzo.svg" target="_self"></a>,
#  <a <img="" href="https://www.cn.sevsu.ru/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/e2f/4bcxnbez3uq8s47lxyuwfpmdrdqyh3eu.svg" target="_self"></a>,
#  <a <img="" href="https://old.sevsu.ru/arab/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/cf2/zup4zfdkt36au65lppgjoh2y0j48zd4m.svg" target="_self"></a>,
#  <a href="https://welcome.sevsu.ru/">
#  <div class="icon header-enrollee"></div>
#                  АБИТУРИЕНТАМ            </a>,
#  <a href="https://old.sevsu.ru/studentam/">
#  <div class="icon header-training"></div>
#                  ОБУЧАЮЩИМСЯ            </a>,
#  <a href="/uni/dap/service-dap">
#  <div class="icon header-employee"></div>
#                  СОТРУДНИКАМ            </a>,
#  <a href="/uni/career">
#  <div class="icon header-graduate"></div>
#                  ВЫПУСКНИКАМ            </a>,
#  <a class="header__menu--link" href="/uni/">Университет</a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg"/>
#  </a>,
#  <a <img="" href="https://www.sevsu.ru/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" target="_self"></a>,
#  <a <img="" href="https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/cf5/lw5pf2vo13ir6mydthsjmclw9swcqkzo.svg" target="_self"></a>,
#  <a <img="" href="https://www.cn.sevsu.ru/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/e2f/4bcxnbez3uq8s47lxyuwfpmdrdqyh3eu.svg" target="_self"></a>,
#  <a <img="" href="https://old.sevsu.ru/arab/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/cf2/zup4zfdkt36au65lppgjoh2y0j48zd4m.svg" target="_self"></a>,
#  <a class="menu-container__return-link" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                  Университет                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/about/" title="Перейти в О СевГУ">
#                                                  О СевГУ                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/rector/" title="Перейти в Страница ректора">
#                                                  Страница ректора                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/nabsovet/" title="Перейти в Наблюдательный совет">
#                                                  Наблюдательный совет                                                                                            </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/uni/academic-board" title="Перейти в Ученый совет">
#                                                  Ученый совет                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Ученый совет                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/academic-board//" style="" title="Состав ученого совета Университета">
#                                                                          Состав ученого совета Университета                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/ab-reg" style="" title="Положение об учёном совете">
#                                                                          Положение об учёном совете                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/ab-rules" style="" title="Регламент работы ученого совета">
#                                                                          Регламент работы ученого совета                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/plan-uch-sovet" style="" title="План работы учёного совета">
#                                                                          План работы учёного совета                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/materials" style="" title="Материалы к ученому совету">
#                                                                          Материалы к ученому совету                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/docs" style="" title="Локальные нормативные документы">
#                                                                          Локальные нормативные документы                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/comission" style="" title="Комиссия ученого совета">
#                                                                          Комиссия ученого совета                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/uni" style="" title="Учёные советы институтов">
#                                                                          Учёные советы институтов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/rus" style="" title="Решения ученого совета">
#                                                                          Решения ученого совета                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/nagrad" style="" title="Наградные материалы">
#                                                                          Наградные материалы                                                                    </a>,
#  <a class="menu-container__link" href="/uni/academic-board/poryadok-prisvoeniya-uchenykh-zvaniy" style="" title="Порядок присвоения ученых званий">
#                                                                          Порядок присвоения ученых званий                                                                    </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/uni/programma-razvitiya" title="Перейти в Программа развития">
#                                                  Программа развития                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Программа развития                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/programma-razvitiya//" style="" title="Главная Программа развития">
#                                                                          Главная Программа развития                                                                    </a>,
#  <a class="menu-container__link" href="/uni/programma-razvitiya/reports" style="" title="Отчеты о реализации программы развития">
#                                                                          Отчеты о реализации программы развития                                                                    </a>,
#  <a class="menu-container__link" href="/uni/programma-razvitiya/projects" style="" title="Проекты программы развития">
#                                                                          Проекты программы развития                                                                    </a>,
#  <a class="menu-container__link" href="/uni/programma-razvitiya/docs" style="" title="Нормативные документы">
#                                                                          Нормативные документы                                                                    </a>,
#  <a class="menu-container__link" href="/uni/programma-razvitiya/prioritet-2030" style="" title="СевГУ — участник программы «Приоритет 2030»">
#                                                                          СевГУ — участник программы «Приоритет 2030»                                                                    </a>,
#  <a class="menu-container__link" href="/uni/conference/" title="Перейти в Конференция работников и обучающихся">
#                                                  Конференция работников и обучающихся                                                                                            </a>,
#  <a class="menu-container__link" href="/sveden/" title="Перейти в Сведения об образовательной организации">
#                                                  Сведения об образовательной организации                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/symbolic/" title="Перейти в Символика университета">
#                                                  Символика университета                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/anticorrupt/" title="Перейти в Противодействие коррупции">
#                                                  Противодействие коррупции                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/ek/" title="Перейти в Эффективный контракт">
#                                                  Эффективный контракт                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/konkurs/" title="Перейти в Конкурс">
#                                                  Конкурс                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/vacancy/" title="Перейти в Вакансии">
#                                                  Вакансии                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/obr2/" title="Перейти в Обращения граждан">
#                                                  Обращения граждан                                                                                            </a>,
#  <a class="menu-container__link" href="https://www.sevsu.ru/uni/dap" rel="nofollow noopener" target="_blank" title="Перейти в Заказать справку">
#                                                  Заказать справку                                                                                            </a>,
#  <a class="menu-container__link" href="/pay/" title="Перейти в Онлайн-оплата">
#                                                  Онлайн-оплата                                                                                            </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/uni/support" title="Перейти в Документы и инструкции по информатизации">
#                                                  Документы и инструкции по информатизации                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Документы и инструкции по информатизации                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/support//" style="" title="Документы и инструкции по информатизации">
#                                                                          Документы и инструкции по информатизации                                                                    </a>,
#  <a class="menu-container__link" href="/uni/support/tekhnicheskaya-podderzhka" style="" title="Техническая поддержка">
#                                                                          Техническая поддержка                                                                    </a>,
#  <a class="menu-container__link" href="/uni/support/zayavka-na-it-soprovozhdenie-meropriyatiya" style="" title="Заявка на ИТ-сопровождение мероприятия">
#                                                                          Заявка на ИТ-сопровождение мероприятия                                                                    </a>,
#  <a class="menu-container__link" href="/uni/support/inye-obshchesistemnye-programmnye-produkty" style="" title="Заявка на установку общесистемных программных продуктов">
#                                                                          Заявка на установку общесистемных программных продуктов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/support/zayavka-na-nastroyku-dorabotku-programmnykh-produktov" style="" title="Заявка на настройку, доработку программных продуктов">
#                                                                          Заявка на настройку, доработку программных продуктов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/support/uchyetn-info" style="" title="Проблемы с учётной информацией">
#                                                                          Проблемы с учётной информацией                                                                    </a>,
#  <a class="menu-container__link" href="/uni/support/oshibka-is-1s" style="" title="Ошибка в ИС семейства 1С">
#                                                                          Ошибка в ИС семейства 1С                                                                    </a>,
#  <a class="menu-container__link" href="/uni/graduates/" title="Перейти в Наши выпускники">
#                                                  Наши выпускники                                                                                            </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/uni/career" title="Перейти в Центр карьеры и трудоустройства">
#                                                  Центр карьеры и трудоустройства                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Центр карьеры и трудоустройства                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/career//" style="" title="Центр карьеры и трудоустройства">
#                                                                          Центр карьеры и трудоустройства                                                                    </a>,
#  <a class="menu-container__link" href="/uni/career/stud" style="" title="Студенту">
#                                                                          Студенту                                                                    </a>,
#  <a class="menu-container__link" href="/uni/career/emp" style="" title="Работодателю">
#                                                                          Работодателю                                                                    </a>,
#  <a class="menu-container__link" href="/uni/career/vypusk" style="" title="Ассоциация выпускников">
#                                                                          Ассоциация выпускников                                                                    </a>,
#  <a class="menu-container__link" href="/uni/career/vacant" style="" title="Вакансии">
#                                                                          Вакансии                                                                    </a>,
#  <a class="menu-container__link" href="/uni/career/resume" style="" title="Отправить резюме">
#                                                                          Отправить резюме                                                                    </a>,
#  <a class="menu-container__link" href="/uni/vu/" title="Перейти в Воинский учет">
#                                                  Воинский учет                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/sotrudnikam/" title="Перейти в Профсоюз">
#                                                  Профсоюз                                                                                            </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/uni/dap" title="Перейти в Дирекция административных процессов (заказать справку)">
#                                                  Дирекция административных процессов (заказать справку)                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Дирекция административных процессов (заказать справку)                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/dap//" style="" title="Дирекция административных процессов">
#                                                                          Дирекция административных процессов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/dohod" style="" title="Подача заявки на выдачу справки о доходах, справки о выплате пособий">
#                                                                          Подача заявки на выдачу справки о доходах, справки о выплате пособий                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/obuchenie" style="" title="Подача заявки на выдачу справки о подтверждении факта обучения">
#                                                                          Подача заявки на выдачу справки о подтверждении факта обучения                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/obuchenie2" style="" title="Справка о периоде обучения или справка об обучении (академка)">
#                                                                          Справка о периоде обучения или справка об обучении (академка)                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/komissariat" style="" title="Справка в военный комиссариат">
#                                                                          Справка в военный комиссариат                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/status" style="" title="Подача заявки на выдачу справки о статусе">
#                                                                          Подача заявки на выдачу справки о статусе                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/copy" style="" title="Подача заявки на выдачу копии документов">
#                                                                          Подача заявки на выдачу копии документов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/vypiska" style="" title="Подача заявки на выдачу выписки из приказа">
#                                                                          Подача заявки на выдачу выписки из приказа                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/copy-ust" style="" title="Подача заявки на выдачу копий уставных документов CевГУ">
#                                                                          Подача заявки на выдачу копий уставных документов CевГУ                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/arhiv-dap" style="" title="Архив">
#                                                                          Архив                                                                    </a>,
#  <a class="menu-container__link" href="/uni/dap/blanc" style="" title="Бланки">
#                                                                          Бланки                                                                    </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/uni/omoo" title="Перейти в Международное сотрудничество">
#                                                  Международное сотрудничество                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Международное сотрудничество                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/uni/omoo//" style="" title="Международное сотрудничество">
#                                                                          Международное сотрудничество                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/oop-ig" style="" title=" Основные образовательные программы">
#                                                                           Основные образовательные программы                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/soc-seti" style="" title="Мы в социальных сетях">
#                                                                          Мы в социальных сетях                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/dokumenty-ms" style="" title="Документы">
#                                                                          Документы                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/stud-ms" style="" title="Международный центр по развитию талантов">
#                                                                          Международный центр по развитию талантов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/m-sogl" style="" title="Международные соглашения">
#                                                                          Международные соглашения                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/meds" style="" title="Медицинская страховка">
#                                                                          Медицинская страховка                                                                    </a>,
#  <a class="menu-container__link" href="/uni/omoo/priz" style="" title="Признание образовательных документов">
#                                                                          Признание образовательных документов                                                                    </a>,
#  <a class="menu-container__link" href="/uni/ldnr/" title="Перейти в Инструкция по поступлению В СевГУ для граждан  ДНР, ЛНР и Украины">
#                                                  Инструкция по поступлению В СевГУ для граждан  ДНР, ЛНР и Украины                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/svo/" title="Перейти в Поступление детей военнослужащих, которые принимали участие в СВО">
#                                                  Поступление детей военнослужащих, которые принимали участие в СВО                                                                                            </a>,
#  <a class="menu-container__link" href="https://old.sevsu.ru/docsssss" rel="nofollow noopener" target="_blank" title="Перейти в Локальные нормативные акты">
#                                                  Локальные нормативные акты                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/dohod/" title="Перейти в Сведения о доходах руководителей и членов их семей">
#                                                  Сведения о доходах руководителей и членов их семей                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/tekhnologicheskoe-predprinimatelstvo/" title="Перейти в Технологическое предпринимательство">
#                                                  Технологическое предпринимательство                                                                                            </a>,
#  <a class="menu-container__link" href="/uni/partners/" title="Перейти в Сотрудничество">
#                                                  Сотрудничество                                                                                            </a>,
#  <a class="header__menu--link" href="/univers/">Образование</a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg"/>
#  </a>,
#  <a <img="" href="https://www.sevsu.ru/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/5ac/kieuvhooez66lzzqjbu33urfv2c7vuqg.svg" target="_self"></a>,
#  <a <img="" href="https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/cf5/lw5pf2vo13ir6mydthsjmclw9swcqkzo.svg" target="_self"></a>,
#  <a <img="" href="https://www.cn.sevsu.ru/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/e2f/4bcxnbez3uq8s47lxyuwfpmdrdqyh3eu.svg" target="_self"></a>,
#  <a <img="" href="https://old.sevsu.ru/arab/admission/item/podat-dokumenty/" rel="nofollow noopener" src="/upload/iblock/cf2/zup4zfdkt36au65lppgjoh2y0j48zd4m.svg" target="_self"></a>,
#  <a class="menu-container__return-link" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                  Образование                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/univers/" title="Перейти в Список институтов">
#                                                  Список институтов                                                                                            </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/univers/pi/" title="Перейти в Политехнический институт">
#                                                  Политехнический институт                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Политехнический институт                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/univers/pi/" style="" title="ПОЛИТЕХНИЧЕСКИЙ ИНСТИТУТ">
#                                                                          ПОЛИТЕХНИЧЕСКИЙ ИНСТИТУТ                                                                    </a>,
#  <a class="menu-container__link" href="/univers/pi/at/" style="" title="Кафедра «Автомобильный транспорт»">
#                                                                          Кафедра «Автомобильный транспорт»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/pi/ptio/" style="" title="Кафедра «Пищевые технологии и оборудование»">
#                                                                          Кафедра «Пищевые технологии и оборудование»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/pi/psiatp/" style="" title="Кафедра «Приборные системы и автоматизация технологических процессов»">
#                                                                          Кафедра «Приборные системы и автоматизация технологических процессов»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/pi/tm/" style="" title="Кафедра «Технология машиностроения»">
#                                                                          Кафедра «Технология машиностроения»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/pi/kafedra-tekhnogennaya-bezopasnost-i-metrologiya/" style="" title="Кафедра «Техногенная безопасность и метрология»">
#                                                                          Кафедра «Техногенная безопасность и метрология»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/pi/kafedra-tsifrovoe-proektirovanie/" style="" title="Кафедра «Цифровое проектирование»">
#                                                                          Кафедра «Цифровое проектирование»                                                                    </a>,
#  <a class="menu-container__link menu-container__link--drop" href="/univers/iyaiep/" title="Перейти в Институт ядерной энергии и промышленности">
#                                                  Институт ядерной энергии и промышленности                                                                                                    <img alt="Декоративная иконка" class="anchor-link__icon" src="/local/html/static/img/content/education/arrow-right.svg"/>
#  </a>,
#  <a class="logout-icon" href="https://lk.sevsu.ru/user/sign-in/login" title="Личный кабинет">
#  <img alt="Личный кабинет" class="select-sight__image" src="/local/html/icon-svg/menu-1.svg"/>
#  </a>,
#  <a class="faint-sight" href="/search/" title="Поиск">
#  <img alt="Поиск" class="select-sight__image" src="/local/html/icon-svg/menu-2.svg"/>
#  </a>,
#  <a class="faint-sight bvi-open" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a href="https://old.sevsu.ru/english/" rel="nofollow noopener" target="_blank">EN</a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_blank">AB</a>,
#  <a href="/">RU</a>,
#  <a class="return-link--level-2" href="#">
#  <img alt="Вернуться назад" class="menu-container__image" src="/local/html/icon-svg/arrow-left.svg"/>
#                                                                  Институт ядерной энергии и промышленности                                                            </a>,
#  <a class="select-language" href="#" title="Смена языка">
#  <img alt="Смена языка" class="select-language__image" src="/local/html/icon-svg/select-language.svg"/>
#  </a>,
#  <a class="faint-sight" href="?special_version=Y" title="Для слабовидящих">
#  <img alt="Для слабовидящих" class="select-sight__image" src="/local/html/icon-svg/ocular.svg"/>
#  </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/" style="" title="ИНСТИТУТ ЯДЕРНОЙ ЭНЕРГИИ И ПРОМЫШЛЕННОСТИ">
#                                                                          ИНСТИТУТ ЯДЕРНОЙ ЭНЕРГИИ И ПРОМЫШЛЕННОСТИ                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/vieess/" style="" title="Кафедра «Возобновляемые источники энергии и электрические системы и сети»">
#                                                                          Кафедра «Возобновляемые источники энергии и электрические системы и сети»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/pu/" style="" title="Кафедра «Паротурбинные установки»">
#                                                                          Кафедра «Паротурбинные установки»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/rieb/" style="" title="Кафедра «Радиоэкология и экологическая безопасность»">
#                                                                          Кафедра «Радиоэкология и экологическая безопасность»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/skiuas/" style="" title="Кафедра «Системы контроля и управления атомных станций»">
#                                                                          Кафедра «Системы контроля и управления атомных станций»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/esas/" style="" title="Кафедра «Электроэнергетические системы атомных станций»">
#                                                                          Кафедра «Электроэнергетические системы атомных станций»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/yaeu/" style="" title="Кафедра «Ядерные энергетические установки»">
#                                                                          Кафедра «Ядерные энергетические установки»                                                                    </a>,
#  <a class="menu-container__link" href="/univers/iyaiep/htas/" style="" title="Кафедра «Химия и химические технологии»">
#                                                                          Кафедра «Химия и химические технологии»                                                                    </a>,
# ...
#  <img src="/upload/iblock/e2f/4bcxnbez3uq8s47lxyuwfpmdrdqyh3eu.svg">
#              CN        </img></a>,
#  <a href="https://old.sevsu.ru/arab/" rel="nofollow noopener" target="_self">
#  <img src="/upload/iblock/cf2/zup4zfdkt36au65lppgjoh2y0j48zd4m.svg">
#              SY        </img></a>,
#  <a class="icon-view-main bvi-open" href="?special_version=Y" itemprop="copy"></a>,
#  <a class="header__lk" href="#"></a>,
#  <a class="main-banner__image-link" href="https://www.sevsu.ru/uni/programma-razvitiya/prioritet-2030/" target="_blank">
#  </a>,
#  <a class="main-banner__image-link" href="/specialnosti/" target="_blank">
#  </a>,
#  <a class="main-cat__item" href="https://www.sevsu.ru/admission/item/85-pravila-priema/" rel="nofollow noopener" target="_blank">Правила приема - 2023</a>,
#  <a class="main-cat__item" href="https://www.sevsu.ru/uni/dap/" rel="nofollow noopener" target="_blank">Заказать справку</a>,
#  <a class="main-cat__item" href="/univers/kursy/pod-kursy/">СДАЕМ ЕГЭ И ОГЭ!</a>,
#  <a aria-controls="pills-home" aria-selected="true" class="nav-link active" data-toggle="pill" href="#pills-home" id="pills-home-tab" role="tab">АНОНСЫ</a>,
#  <a aria-controls="pills-profile" aria-selected="false" class="nav-link" data-toggle="pill" href="#pills-profile" id="pills-profile-tab" role="tab">ОБЪЯВЛЕНИЯ</a>,
#  <a :href="item.URL" :key="item.ID" class="d-flex main-announcement__item" v-for="item in itemsAnons">
#  <div class="main-announcement__date" v-html="formatDate(item.DATE)" v-if="item.NO_DATE == 'N'"></div>
#  <div class="main-announcement__date" v-if="item.NO_DATE == 'Y'">
#  <img alt="" src="/local/templates/sevgu/static/img/content/attention.svg"/>
#  </div>
#  <div class="main-announcement__content">
#  <h4 v-html="item.NAME"></h4>
#  <p v-html="item.PREVIEW"></p>
#  <div class="main-announcement__more">Читать далее...</div>
#  </div>
#  </a>,
#  <a class="button btn-blue ml-auto" href="/novosti/anonsy/?tab=announce">ПОДРОБНЕЕ</a>,
#  <a :href="item.URL" :key="item.ID" class="d-flex main-announcement__item attention" v-for="item in itemsPromo">
#  <div class="main-announcement__date" v-html="formatDate(item.DATE)"></div>
#  <div class="main-announcement__content">
#  <h4 v-html="item.NAME"></h4>
#  <p v-html="item.PREVIEW"></p>
#  <div class="main-announcement__more">Читать далее...</div>
#  </div>
#  </a>,
#  <a class="button btn-blue ml-auto" href="/novosti/anonsy/?tab=promo">ПОДРОБНЕЕ</a>,
#  <a class="inherit-color" href="/novosti/?section=9" style="text-decoration: none">СЕВГУ СЕЙЧАС</a>,
#  <a class="main-info__item--title" href="/novosti/item/seminar_praktikum_predmetno_prostranstvennaya_sreda_sovremennogo_doshkolnogo_uchrezhdeniya/" target="_blank">Семинар-практикум «Предметно-пространственная среда  современного дошкольного учреждения»</a>,
#  <a class="main-info__more" href="/novosti/item/seminar_praktikum_predmetno_prostranstvennaya_sreda_sovremennogo_doshkolnogo_uchrezhdeniya/" target="_blank">Читать далее...</a>,
#  <a class="main-info__item--title" href="/novosti/item/s_vsemirnym_dnyem_futbola/" target="_blank">С ВСЕМИРНЫМ ДНЁМ ФУТБОЛА!</a>,
#  <a class="main-info__more" href="/novosti/item/s_vsemirnym_dnyem_futbola/" target="_blank">Читать далее...</a>,
#  <a class="main-info__item--title" href="/novosti/item/energiya_dostizheniy_more_vozmozhnostey/" target="_blank">ЭНЕРГИЯ ДОСТИЖЕНИЙ, МОРЕ ВОЗМОЖНОСТЕЙ</a>,
#  <a class="main-info__more" href="/novosti/item/energiya_dostizheniy_more_vozmozhnostey/" target="_blank">Читать далее...</a>,
#  <a class="main-info__item--title" href="/novosti/item/studenty_gruppy_la_b_22_1_o_posetili_muzey_chernomorskogo_flota_rossiyskoy_federatsii/" target="_blank">Студенты группы ЛА/б -22-1-о посетили музей Черноморского флота Российской Федерации.</a>,
#  <a class="main-info__more" href="/novosti/item/studenty_gruppy_la_b_22_1_o_posetili_muzey_chernomorskogo_flota_rossiyskoy_federatsii/" target="_blank">Читать далее...</a>,
#  <a class="main-info__item--title" href="/novosti/item/startap_po_sozdaniyu_is_dlya_unifikatsii_inforesursov_sevastopolya_vysoko_otsenili_eksperty_sititekh/" target="_blank">Стартап по созданию ИС для унификации инфоресурсов Севастополя высоко оценили эксперты «СитиТеха»</a>,
#  <a class="main-info__more" href="/novosti/item/startap_po_sozdaniyu_is_dlya_unifikatsii_inforesursov_sevastopolya_vysoko_otsenili_eksperty_sititekh/" target="_blank">Читать далее...</a>,
#  <a class="main-info__item--title" href="/novosti/item/intensivy_po_vedeniyu_gospablikov_proshli_v_tochke_kipeniya_sevgu/" target="_blank">Интенсивы по ведению госпабликов прошли в Точке кипения СевГУ</a>,
#  <a class="main-info__more" href="/novosti/item/intensivy_po_vedeniyu_gospablikov_proshli_v_tochke_kipeniya_sevgu/" target="_blank">Читать далее...</a>,
#  <a class="news-item__block" href="/novosti/item/startap_po_sozdaniyu_is_dlya_unifikatsii_inforesursov_sevastopolya_vysoko_otsenili_eksperty_sititekh/">
#  <div class="news-item__image">
#  <img alt="" src="/upload/iblock/060/qo3ad0skrkzd74hj2adk91p6thq3msh0.JPG"/>
#  </div>
#  <div class="news-item__content">
#  <div class="news-item__date">
#                                  09 <span>декабря</span> </div>
#  <h3>Стартап по созданию ИС для унификации инфоресурсов Севастополя высоко оценили эксперты «СитиТеха»</h3>
#  <p>Подведены итоги работы акселератора «Сититех» - уникальной программы для развития технологических проектов с высоким потенциалом, где студенческие команды в течение двух месяцев создавали свои...</p>
#  </div>
#  </a>,
#  <a class="news-item__block" href="/novosti/item/intensivy_po_vedeniyu_gospablikov_proshli_v_tochke_kipeniya_sevgu/">
#  <div class="news-item__image">
#  <img alt="" src="/upload/iblock/38d/047mzjo0uxfjr0h6spnttgiqzmrptibv.JPG"/>
#  <div class="news__image-label">
#  <img src="/upload/medialibrary/a29/wlo424k6kl8ymr4vmdba7htng42lj37h.png"/>
#  </div>
#  </div>
#  <div class="news-item__content">
#  <div class="news-item__date">
#                                  09 <span>декабря</span> </div>
#  <h3>Интенсивы по ведению госпабликов прошли в Точке кипения СевГУ</h3>
#  <p>С 1 декабря в России вступил в силу «Закон о госпабликах». Он предполагает, что все органы власти и подведомственные учреждения должны завести аккаунты во «ВКонтакте» или в «Одноклассниках» и...</p>
#  </div>
#  </a>,
#  <a class="news-item__block" href="/novosti/item/konferentsiya_priurochennaya_ko_dnyu_konstitutsii_rf_proshla_v_sevgu/">
#  <div class="news-item__image">
#  <img alt="" src="/upload/iblock/35c/plw1brmtjzjr44yw1d1287t4qz5pauur.JPG"/>
#  </div>
#  <div class="news-item__content">
#  <div class="news-item__date">
#                                  09 <span>декабря</span> </div>
#  <h3>Конференция, приуроченная ко Дню конституции РФ, прошла в СевГУ</h3>
#  <p>На базе Севастопольского центра избирательного права и процесса Севастопольского госуниверситета прошла научно-практическая конференция, приуроченная ко Дню конституции Российской Федерации, который...</p>
#  </div>
#  </a>,
#  <a class="news-item__block" href="/novosti/item/prepodavateli_russkogo_yazyka_iz_sirii_obuchayutsya_v_sevgu_videosyuzhety/">
#  <div class="news-item__image">
#  <img alt="" src="/upload/iblock/41a/whx13b4bmn8hsz59o3wd8n34tufpz9pv.JPG"/>
#  </div>
#  <div class="news-item__content">
#  <div class="news-item__date">
#                                  09 <span>декабря</span> </div>
#  <h3>Преподаватели русского языка из Сирии обучаются в СевГУ. Видеосюжеты</h3>
#  <p>Преподаватели русского языка из Сирии проходят повышение квалификации в Севастопольском государственном университете. Программа рассчитана на три месяца. За это время специалисты познакомятся с...</p>
#  </div>
#  </a>,
#  <a class="news-item__block" href="/novosti/item/studenty_gradostroiteli_prokhodyat_praktiku_na_klyuchevom_kulturnom_obekte_sevastopolya_myse_khrusta/">
#  <div class="news-item__image">
#  <img alt="" src="/upload/iblock/0c6/2pvclxu600nprho07q8so1bhxr6m5h08.JPG"/>
#  </div>
#  <div class="news-item__content">
#  <div class="news-item__date">
#                                  08 <span>декабря</span> </div>
#  <h3>Студенты-градостроители проходят практику на ключевом культурном объекте Севастополя</h3>
#  <p>Пятеро студентов направления «Промышленное и гражданское строительство» Института развития города СевГУ проходят практику на стройплощадке Севастопольского театра оперы и балета на мысе Хрустальный....</p>
#  </div>
#  </a>,
#  <a class="news-item__block" href="/novosti/item/studenty_sevgu_prinyali_uchastie_v_forume_molodykh_professionalov_atomprofi/">
#  <div class="news-item__image">
#  <img alt="" src="/upload/iblock/d30/74uajdm3vns1lnb5kx5hjzdpk9cyk2cm.jpeg"/>
#  </div>
#  <div class="news-item__content">
#  <div class="news-item__date">
#                                  08 <span>декабря</span> </div>
#  <h3>Студенты СевГУ приняли участие в Форуме молодых профессионалов AtomProfi</h3>
#  <p>Участниками крупнейшего молодежного мероприятия атомной отрасли стали трое студентов Института ядерной энергии и промышленности СевГУ Дмитрий Менюк, Валерий Исеев и Илья Дюдяев. </p>
#  </div>
#  </a>,
#  <a class="button btn-blue ml-auto" href="/novosti/?main_news=y">ВСЕ НОВОСТИ</a>,
#  <a class="video-item__title" href="/novosti/videoarhiv/73637/">СевГУ: учись у теплого моря</a>,
#  <a class="video-item__title" href="/novosti/videoarhiv/73610/">Покажу СевГУ: Политех</a>,
#  <a class="video-item__title" href="/novosti/videoarhiv/73629/">Покажу СевГУ: Юридический институт</a>,
#  <a class="video-item__title" href="/novosti/videoarhiv/73646/">СевГУ на «Первом»: в Севастополе разрабатывают систему подводного стереозрения</a>,
#  <a class="button btn-blue ml-auto" href="/novosti/videoarhiv/">ВСЕ ВИДЕО</a>,
#  <a class="inherit-color" href="/partners" style="text-decoration: none">ПАРТНЕРЫ</a>,
#  <a href="https://tsuab.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Томский государственный архитектурно-строительный университет" src="/upload/iblock/c4d/c4d76e43785f897892e389303420545a.png"/>
#  </div>
#  </a>,
#  <a href="http://academy21.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Чувашская государственная сельскохозяйственная академия" src="/upload/iblock/037/0370ddc381799b3c031a49a8e3e736e2.png"/>
#  </div>
#  </a>,
#  <a href="http://www.fa.ru/Pages/Home.aspx" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Финансовый университет при Правительстве Российской Федерации" src="/upload/iblock/e2e/e2edacdbfe1f6ecb16acfbea1bce58a6.png"/>
#  </div>
#  </a>,
#  <a href="http://nikitasad.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Никитский ботанический сад – Национальный научный центр РАН" src="/upload/iblock/695/695bbdc39580efd0de37d704d16f64ad.png"/>
#  </div>
#  </a>,
#  <a href="https://rsue.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Ростовский государственный экономический университет" src="/upload/iblock/7b2/7b24420f84aff57afcfcbea06763121b.png"/>
#  </div>
#  </a>,
#  <a href="https://www.sechenov.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Сеченовский Университет" src="/upload/iblock/01e/01ec9a2a3736db33a5ceff0075f989c6.png"/>
#  </div>
#  </a>,
#  <a href="http://www.penzgtu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Пензенский государственный технологический университет" src="/upload/iblock/774/7746b2e3ad1cc7d93307a0a73adc800a.png"/>
#  </div>
#  </a>,
#  <a href="https://nspu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="ФГБОУ ВО Новосибирский государственный педагогический университет" src="/upload/iblock/8b3/8b343f462ea2b2e5d2cd4213c2b545aa.png"/>
#  </div>
#  </a>,
#  <a href="http://www.sibstrin.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Новосибирский государственный архитектурно- строительный университет (СИБСТРИН)" src="/upload/iblock/4b2/4b25c1d178e50ca7379b0970f8624b71.png"/>
#  </div>
#  </a>,
#  <a href="http://igras.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Институт географии РАН" src="/upload/iblock/26b/26b3e31d45c35cf3944361e1ac73b1bb.png"/>
#  </div>
#  </a>,
#  <a href="https://donstu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Донской государственный технический университет" src="/upload/iblock/db7/db7ee9bd737fcf190331ab2ba8c6a84b.png"/>
#  </div>
#  </a>,
#  <a href="https://kursksu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Курский государственный университет" src="/upload/iblock/aff/aff086b0f225f0fa835d967a426dbd32.png"/>
#  </div>
#  </a>,
#  <a href="https://spbu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Санкт-Петербургский государственный университет" src="/upload/iblock/014/0144db1bc465f2dfc5816653de54eb06.png"/>
#  </div>
#  </a>,
#  <a href="https://guu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Государственный университет управления" src="/upload/iblock/e6b/e6b9dffa305b5ae30a208c02c5360d90.png"/>
#  </div>
#  </a>,
#  <a href="https://volsu.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Волгоградский государственный университет" src="/upload/iblock/08a/08a7d735d3c1d79493edadd2a464aa14.png"/>
#  </div>
#  </a>,
#  <a href="https://bashedu.ru/ru" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Башкирский государственный университет" src="/upload/iblock/c0c/c0c5a8e07360af7f7efa4a39c9065532.png"/>
#  </div>
#  </a>,
#  <a href="http://mpgu.su/" target="_blank">
#  <div class="main-partners__image">
#  <img alt="Московский педагогический государственный университет" src="/upload/iblock/001/001c4e3d96a6223a95f5cb710ebef3d9.png"/>
#  </div>
#  </a>,
#  <a href="http://www.sevmash.ru/" target="_blank">
#  <div class="main-partners__image">
#  <img alt='ОАО ПО "Севмаш"' src="/upload/iblock/b37/b37efa70d8cbfbf8b873917fda53bcc5.png"/>
#  </div>
#  </a>,
#  <a href="/univers/">
#                  Институты            </a>,
#  <a href="/specialnosti/">
#                  Направления подготовки            </a>,
#  <a href="/uni/omo/ppig/">
#                  Иностранным гражданам            </a>,
#  <a href="/infrastruktura/">
#                  Вне учебы            </a>,
#  <a href="/sveden/">
#                  Сведения об образовательной организации            </a>,
#  <a href="https://welcome.sevsu.ru/">
#                  Абитуриентам            </a>,
#  <a href="/univers/kursy/pod-kursy/">
#                  Подготовка к ЕГЭ            </a>,
#  <a href="/admission/item/85-pravila-priema/">
#                  Правила приема            </a>,
#  <a data-bs-target="#modal__found-error" data-bs-toggle="modal" href="#">
#                  Сообщить об ошибке на странице            </a>,
#  <a href="/kontakty/">
#                  Контакты            </a>,
#  <a href="https://old.sevsu.ru/activnost/svyaz/">
#                  Сообщить о проблеме            </a>,
#  <a class="footer__logo" href="/">
#  <img alt="" src="/local/templates/sevgu/static/img/content/logo-footer.svg"/>
#  </a>,
#  <a class="footer__version bvi-open" href="?special_version=Y">
#  <div class="icon icon-version-white"></div>
#                                  Версия для слабовидящих                            </a>,
#  <a class="footer__soc-icon footer-vk" href="https://vk.com/sevsu/" target="_blank"></a>,
#  <a class="footer__soc-icon footer-youtube" href="https://www.youtube.com/channel/UC1rFaFbJ4pDQgnrolyDfq0g/" target="_blank"></a>,
#  <a class="footer__soc-icon footer-telegram" href="https://www.t.me/sevsu_live/" target="_blank"></a>,
#  <a class="footer__soc-icon footer-ok" href="https://ok.ru/group/61479744110674" target="_blank"></a>,
#  <a class="footer__soc-icon footer-rutube" href="https://rutube.ru/channel/25013780/" target="_blank"></a>,
#  <a class="footer__soc-icon footer-mpr" href="https://edu.gov.ru/" target="_blank"></a>,
#  <a class="footer__soc-icon footer-mnor" href="https://www.minobrnauki.gov.ru/" target="_blank"></a>,
#  <a class="footer__version bvi-open" href="?special_version=Y">
#  <div class="icon icon-version-white"></div>
#                                  Версия для слабовидящих                            </a>,
#  <a class="__cf_email__" data-cfemail="f8888a9d8b8bb88b9d8e8b8dd6" href="/cdn-cgi/l/email-protection">[email protected]</a>]

# %% [markdown]
# As you can see, the findAll() method (or its abbreviated form of writing in the form of just parentheses) searches not
# only for the immediate "children" of some vertex (in genealogical terms), but also for all
# descendants.

# %%
#Let's print the links ourselves
for link in page("a"):
    if link.get("href")!=None:
        print(link["href"])
# Out:
# /admission/
# tel:+7 (8692) 222-911
# /cdn-cgi/l/email-protection#a3d3d1cac6cee3d0c6d5d0d68dd1d6
# https://www.sevsu.ru
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://www.sevsu.ru/admission/item/podat-dokumenty/
# https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/
# https://www.cn.sevsu.ru/admission/item/podat-dokumenty/
# https://old.sevsu.ru/arab/admission/item/podat-dokumenty/
# https://welcome.sevsu.ru/
# https://old.sevsu.ru/studentam/
# /uni/dap/service-dap
# /uni/career
# /uni/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://www.sevsu.ru/admission/item/podat-dokumenty/
# https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/
# https://www.cn.sevsu.ru/admission/item/podat-dokumenty/
# https://old.sevsu.ru/arab/admission/item/podat-dokumenty/
# #
# #
# ?special_version=Y
# /uni/about/
# /uni/rector/
# /uni/nabsovet/
# /uni/academic-board
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /uni/academic-board//
# /uni/academic-board/ab-reg
# /uni/academic-board/ab-rules
# /uni/academic-board/plan-uch-sovet
# /uni/academic-board/materials
# /uni/academic-board/docs
# /uni/academic-board/comission
# /uni/academic-board/uni
# /uni/academic-board/rus
# /uni/academic-board/nagrad
# /uni/academic-board/poryadok-prisvoeniya-uchenykh-zvaniy
# /uni/programma-razvitiya
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /uni/programma-razvitiya//
# /uni/programma-razvitiya/reports
# /uni/programma-razvitiya/projects
# /uni/programma-razvitiya/docs
# /uni/programma-razvitiya/prioritet-2030
# /uni/conference/
# /sveden/
# /uni/symbolic/
# /uni/anticorrupt/
# /uni/ek/
# /uni/konkurs/
# /uni/vacancy/
# /uni/obr2/
# https://www.sevsu.ru/uni/dap
# /pay/
# /uni/support
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /uni/support//
# /uni/support/tekhnicheskaya-podderzhka
# /uni/support/zayavka-na-it-soprovozhdenie-meropriyatiya
# /uni/support/inye-obshchesistemnye-programmnye-produkty
# /uni/support/zayavka-na-nastroyku-dorabotku-programmnykh-produktov
# /uni/support/uchyetn-info
# /uni/support/oshibka-is-1s
# /uni/graduates/
# /uni/career
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /uni/career//
# /uni/career/stud
# /uni/career/emp
# /uni/career/vypusk
# /uni/career/vacant
# /uni/career/resume
# /uni/vu/
# /uni/sotrudnikam/
# /uni/dap
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /uni/dap//
# /uni/dap/dohod
# /uni/dap/obuchenie
# /uni/dap/obuchenie2
# /uni/dap/komissariat
# /uni/dap/status
# /uni/dap/copy
# /uni/dap/vypiska
# /uni/dap/copy-ust
# /uni/dap/arhiv-dap
# /uni/dap/blanc
# /uni/omoo
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /uni/omoo//
# /uni/omoo/oop-ig
# /uni/omoo/soc-seti
# /uni/omoo/dokumenty-ms
# /uni/omoo/stud-ms
# /uni/omoo/m-sogl
# /uni/omoo/meds
# /uni/omoo/priz
# /uni/ldnr/
# /uni/svo/
# https://old.sevsu.ru/docsssss
# /uni/dohod/
# /uni/tekhnologicheskoe-predprinimatelstvo/
# /uni/partners/
# /univers/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://www.sevsu.ru/admission/item/podat-dokumenty/
# https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/
# https://www.cn.sevsu.ru/admission/item/podat-dokumenty/
# https://old.sevsu.ru/arab/admission/item/podat-dokumenty/
# #
# #
# ?special_version=Y
# /univers/
# /univers/pi/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/pi/
# /univers/pi/at/
# /univers/pi/ptio/
# /univers/pi/psiatp/
# /univers/pi/tm/
# /univers/pi/kafedra-tekhnogennaya-bezopasnost-i-metrologiya/
# /univers/pi/kafedra-tsifrovoe-proektirovanie/
# /univers/iyaiep/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/iyaiep/
# /univers/iyaiep/vieess/
# /univers/iyaiep/pu/
# /univers/iyaiep/rieb/
# /univers/iyaiep/skiuas/
# /univers/iyaiep/esas/
# /univers/iyaiep/yaeu/
# /univers/iyaiep/htas/
# /univers/iriib/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/iriib/
# /univers/iriib/ir/
# /univers/iriib/energynet/
# /univers/iriib/marinet/
# /univers/iriib/proginj-bio/
# /univers/iriib/aeronet/
# /univers/iriib/kafedra-innovatsionnye-telekommunikatsionnye-tekhnologii/
# /univers/iriib/iiuvts/
# /univers/iriib/kafedra-radioelektronnye-sistemy-i-tekhnologii/
# /univers/iriib/et/
# /univers/iituts/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/iituts/
# /univers/iituts/is/
# /univers/iituts/itiks/
# /univers/iituts/cis/
# /univers/iituts/ib/
# /univers/mi/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/mi/
# /univers/mi/oik/
# /univers/mi/se/
# /univers/mi/sibs/
# /univers/mi/eimsis/
# /univers/mi/bazovaya-kafedra-morskie-tekhnologii/
# /univers/irgor/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/irgor/
# /univers/irgor/kad/
# /univers/irgor/ksz/
# /univers/irgor/kgmu/
# /univers/irgor/ka/
# /univers/irgor/ktsg/
# /univers/irgor/bazovaya-kafedra-vinogradarstvo-i-vinodelie-magarach/
# /univers/ionmo/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/ionmo/
# /univers/ionmo/laboratoriya-istoriko-arkheologicheskaya/
# /univers/ionmo/kafedra-russkiy-yazyk-kak-inostrannyy/
# /univers/ionmo/bazovaya-kafedra-slavyanovedenie-i-balkanistika/
# /univers/ionmo/bazovaya-kafedra-istoriya-bolshogo-sredizemnomorya/
# /univers/ionmo/iyamo/
# /univers/ionmo/history/
# /univers/ionmo/sc/
# /univers/ionmo/rgf/
# /univers/ionmo/tpp/
# /univers/ionmo/bazovaya-kafedra-vostokovedenie/
# /univers/ionmo/tir/
# /univers/ionmo/bazovaya-kafedra-arkheologiya/
# /univers/ionmo/mozr/
# /univers/ionmo/pmo/
# /univers/ionmo/md/
# /univers/gpi/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/gpi/
# /univers/gpi/kafedra-spetsialnaya-pedagogika-i-psikhologiya/
# /univers/gpi/bazovaya-kafedra-integrativnaya-didaktika/
# /univers/gpi/bazovaya-kafedra-professionalnoe-razvitie-pedagogicheskikh-kadrov/
# /univers/gpi/dn-o/
# /univers/gpi/ped/
# /univers/gpi/oppp/
# /univers/gpi/pptr/
# /univers/yui/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/yui/
# /univers/yui/gpp/
# /univers/yui/kap/
# /univers/yui/mtp/
# /univers/yui/upp/
# /univers/yui/fkp/
# /univers/yui/tigp/
# /univers/yui/kafedra-trudovoe-pravo/
# /univers/yui/kriminalisticheskaya-laboratoriya-/
# /univers/yui/nauchno-ekspertnyy-tsentr-mezhdunarodnoe-i-otechestvennoe-pravo/
# /univers/yui/uchebnyy-zal-sudebnykh-zasedaniy-/
# /univers/yui/sevastopolskiy-tsentr-izbiratelnogo-prava-i-protsessa/
# /univers/yui/studencheskaya-pravovaya-konsultatsiya-yuridicheskaya-klinika/
# /univers/yui/bazovaya-kafedra-antimonopolnoe-regulirovanie/
# /univers/yui/bazovaya-kafedra-pravotvorchestvo-i-yuridicheskaya-tekhnika/
# /univers/ifeiu/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/ifeiu/
# /univers/ifeiu/buaa/
# /univers/ifeiu/mo/
# /univers/ifeiu/ep/
# /univers/ifeiu/fk/
# /univers/institut_perspektivnykh_issledovaniy/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/institut_perspektivnykh_issledovaniy/
# /univers/institut_perspektivnykh_issledovaniy/kafedra-kompleksnye-biologicheskie-issledovaniya/
# /univers/institut_perspektivnykh_issledovaniy/enen/
# /univers/institut_perspektivnykh_issledovaniy/bazovaya-kafedra-morskie-nauki-i-tekhnologii/
# /univers/institut_perspektivnykh_issledovaniy/bazovaya-kafedra-monitoring-i-teoriya-klimata/
# /univers/institut_perspektivnykh_issledovaniy/vm/
# /univers/institut_perspektivnykh_issledovaniy/fiz/
# /univers/sports/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/sports/
# /univers/sports/kafedra-organizatsii-zdravookhraneniya-i-sestrinskoe-delo-ye/
# /univers/sports/kafedra-fizicheskoe-vospitanie-i-sport/
# /univers/mk/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/mk/
# /univers/mk/otdelenie-sudovozhdeniya/
# /univers/mk/otdelenie-sudovoy-energetiki/
# /univers/mk/otdelenie-tekhniko-ekonomicheskoe/
# /univers/mk/nastavnichestvo/
# /univers/voennyy_uchebnyy_tsentr/
# /univers/drop/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /univers/drop/
# /univers/drop/SOPKUR/
# /univers/drop/asp/
# /univers/drop/s-licenz/
# /univers/drop/s-raspis/
# /univers/idpo
# /univers/lycee
# /specialnosti/
# /univers/kursy/pod-kursy/
# /univers/urbotech
# /univers/cmit
# /univers/center_for_student_trajectories/
# /univers/pod-ft/
# /univers/iop/
# /univers/shedule
# /univers/perevod
# /univers/io
# /univers/accred
# /univers/sp-zfo
# /univers/iot/
# /activnost/worldskills
# https://www.sevsu.ru/sveden/education/
# /univers/proektnoe-obuchenie-studentov/
# /univers/univers/studencheskiy-akselerator/
# /univers/online-edu/
# /univers/youth-grants/
# https://old.sevsu.ru/nauka
# /innovation/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://www.sevsu.ru/admission/item/podat-dokumenty/
# https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/
# https://www.cn.sevsu.ru/admission/item/podat-dokumenty/
# https://old.sevsu.ru/arab/admission/item/podat-dokumenty/
# #
# #
# ?special_version=Y
# /innovation/
# /innovation/podderzhka-startapov-akseleratory/
# /innovation/mip/
# /innovation/infrastructure
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /innovation/infrastructure//
# /innovation/infrastructure/tsentr-transfera-tekhnologiy
# /innovation/infrastructure/esj
# /innovation/infrastructure/laboratorii-i-nauchnye-tsentry
# /innovation/karta
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /innovation/karta//
# /innovation/karta/teh-nap
# /innovation/karta/gum-nap
# /innovation/zakazat-niokr-uslugi-unu-i-tskp
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /innovation/zakazat-niokr-uslugi-unu-i-tskp//
# /innovation/zakazat-niokr-uslugi-unu-i-tskp/infrastruktura
# /innovation/zakazat-niokr-uslugi-unu-i-tskp/unu-tskp
# /innovation/zakazat-niokr-uslugi-unu-i-tskp/zakaz-niokr
# /innovation/predstavitelstvo-fonda-sodeystviya-innovatsiyam
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /innovation/predstavitelstvo-fonda-sodeystviya-innovatsiyam//
# /innovation/predstavitelstvo-fonda-sodeystviya-innovatsiyam/umnik
# /innovation/servis-innovation
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://old.sevsu.ru/english/
# https://old.sevsu.ru/arab/
# /
# #
# #
# ?special_version=Y
# /innovation/servis-innovation//
# /innovation/servis-innovation/umnik-sev
# /innovation/servis-innovation/vnut-grant
# /innovation/servis-innovation/info-konkurs
# /innovation/servis-innovation/info-zakupki
# /innovation/servis-innovation/sopr-grant
# /innovation/servis-innovation/sopr-proj
# /innovation/servis-innovation/sozd-mip
# /innovation/servis-innovation/reg-rid
# /innovation/servis-innovation/zaklyuchenie-dogovorov-na-vypolnenie-niokr
# /priority-2030/
# /activnost/
# https://lk.sevsu.ru/user/sign-in/login
# /search/
# ?special_version=Y
# #
# https://www.sevsu.ru/admission/item/podat-dokumenty/
# https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/
# https://www.cn.sevsu.ru/admission/item/podat-dokumenty/
# https://old.sevsu.ru/arab/admission/item/podat-dokumenty/
# #
# #
# ?special_version=Y
# /activnost/mediacenter
# /activnost/sea-start/
# /activnost/mkc/
# /activnost/o-s-o/
# /activnost/akd
# https://old.sevsu.ru/activnost/svyaz
# /activnost/six-museums
# /activnost/vesna-pobedy
# /activnost/materials
# /activnost/discipline
# /activnost/covid-2019
# /activnost/75
# /activnost/100-let
# /activnost/vakcina
# /activnost/80
# /activnost/okon
# /activnost/polk-nauk
# https://www.sevsu.ru/infrastruktura/biblioteka
# /infrastruktura/sportcomplex/
# https://www.sevsu.ru//infrastruktura/eat
# /infrastruktura/sol-horizont/
# https://www.sevsu.ru//infrastruktura/mk
# https://www.sevsu.ru/infrastruktura/dorm/
# /infrastruktura/point/
# /novosti/
# #
# https://www.sevsu.ru/admission/item/podat-dokumenty/
# https://www.sevsu.ru/uni/omoo/pkig//admission/item/podat-dokumenty/
# https://www.cn.sevsu.ru/admission/item/podat-dokumenty/
# https://old.sevsu.ru/arab/admission/item/podat-dokumenty/
# #
# https://lk.sevsu.ru/user/sign-in/login/
# #
# #
# https://www.sevsu.ru/
# https://www.sevsu.ru/uni/omoo/pkig//
# https://www.cn.sevsu.ru/
# https://old.sevsu.ru/arab/
# ?special_version=Y
# #
# https://www.sevsu.ru/uni/programma-razvitiya/prioritet-2030/
# /specialnosti/
# https://www.sevsu.ru/admission/item/85-pravila-priema/
# https://www.sevsu.ru/uni/dap/
# /univers/kursy/pod-kursy/
# #pills-home
# #pills-profile
# /novosti/anonsy/?tab=announce
# /novosti/anonsy/?tab=promo
# /novosti/?section=9
# /novosti/item/seminar_praktikum_predmetno_prostranstvennaya_sreda_sovremennogo_doshkolnogo_uchrezhdeniya/
# /novosti/item/seminar_praktikum_predmetno_prostranstvennaya_sreda_sovremennogo_doshkolnogo_uchrezhdeniya/
# /novosti/item/s_vsemirnym_dnyem_futbola/
# /novosti/item/s_vsemirnym_dnyem_futbola/
# /novosti/item/energiya_dostizheniy_more_vozmozhnostey/
# /novosti/item/energiya_dostizheniy_more_vozmozhnostey/
# /novosti/item/studenty_gruppy_la_b_22_1_o_posetili_muzey_chernomorskogo_flota_rossiyskoy_federatsii/
# /novosti/item/studenty_gruppy_la_b_22_1_o_posetili_muzey_chernomorskogo_flota_rossiyskoy_federatsii/
# /novosti/item/startap_po_sozdaniyu_is_dlya_unifikatsii_inforesursov_sevastopolya_vysoko_otsenili_eksperty_sititekh/
# /novosti/item/startap_po_sozdaniyu_is_dlya_unifikatsii_inforesursov_sevastopolya_vysoko_otsenili_eksperty_sititekh/
# /novosti/item/intensivy_po_vedeniyu_gospablikov_proshli_v_tochke_kipeniya_sevgu/
# /novosti/item/intensivy_po_vedeniyu_gospablikov_proshli_v_tochke_kipeniya_sevgu/
# /novosti/item/startap_po_sozdaniyu_is_dlya_unifikatsii_inforesursov_sevastopolya_vysoko_otsenili_eksperty_sititekh/
# /novosti/item/intensivy_po_vedeniyu_gospablikov_proshli_v_tochke_kipeniya_sevgu/
# /novosti/item/konferentsiya_priurochennaya_ko_dnyu_konstitutsii_rf_proshla_v_sevgu/
# /novosti/item/prepodavateli_russkogo_yazyka_iz_sirii_obuchayutsya_v_sevgu_videosyuzhety/
# /novosti/item/studenty_gradostroiteli_prokhodyat_praktiku_na_klyuchevom_kulturnom_obekte_sevastopolya_myse_khrusta/
# /novosti/item/studenty_sevgu_prinyali_uchastie_v_forume_molodykh_professionalov_atomprofi/
# /novosti/?main_news=y
# /novosti/videoarhiv/73637/
# /novosti/videoarhiv/73610/
# /novosti/videoarhiv/73629/
# /novosti/videoarhiv/73646/
# /novosti/videoarhiv/
# /partners
# https://tsuab.ru/
# http://academy21.ru/
# http://www.fa.ru/Pages/Home.aspx
# http://nikitasad.ru/
# https://rsue.ru/
# https://www.sechenov.ru/
# http://www.penzgtu.ru/
# https://nspu.ru/
# http://www.sibstrin.ru/
# http://igras.ru/
# https://donstu.ru/
# https://kursksu.ru/
# https://spbu.ru/
# https://guu.ru/
# https://volsu.ru/
# https://bashedu.ru/ru
# http://mpgu.su/
# http://www.sevmash.ru/
# /univers/
# /specialnosti/
# /uni/omo/ppig/
# /infrastruktura/
# /sveden/
# https://welcome.sevsu.ru/
# /univers/kursy/pod-kursy/
# /admission/item/85-pravila-priema/
# #
# /kontakty/
# https://old.sevsu.ru/activnost/svyaz/
# /
# ?special_version=Y
# https://vk.com/sevsu/
# https://www.youtube.com/channel/UC1rFaFbJ4pDQgnrolyDfq0g/
# https://www.t.me/sevsu_live/
# https://ok.ru/group/61479744110674
# https://rutube.ru/channel/25013780/
# https://edu.gov.ru/
# https://www.minobrnauki.gov.ru/
# ?special_version=Y
# /cdn-cgi/l/email-protection

# %% [markdown]
# There are external hyperlinks that start with http, and local ones that lead to the same
# site and are relative (that is, before 1516/topology2.php you need to write
# http://www.sevsu.ru/ to get the full link to the relevant document).

# %% [markdown]
# Now it is clear how our robot should act: for each of the received links, it should
# load the corresponding page, find all the links on it, add them to the queue for
# research, etc. This is about how web crawlers of search engines work. (Although, of course, they
# are much more complicated.)

# %% [markdown]
# ### P.S. Documentation is your friend

# %% [markdown]
# For BeautifulSoup, the documentation is here (http://www.crummy.com/software/BeautifulSoup/bs4/doc/),
# and for requests here (http://docs.python-requests.org/en/latest/) (start with Quickstart). Of course, it's in
# English, but as my programming teacher said, "after six months of programming classes
# , you will consider English a subset of Russian."

# %% [markdown]
# Another source of information about libraries is the same web search, which will most often
# give links to a website with questions and answers http://stackoverflow.com/ (http://stackoverflow.com/).
# For example, typing how to parse table with beautifulsoup (https://www.google.ru/search?q=how+to+parse+table+with+beautifulsoup&gws_rd=cr&ei=wXaJVvzQKIfXyQO4v4PYDw) you will get
# some links to stackoverflow with code examples. By the way, you can also ask your
# own questions on stackoverflow — but first you need to make sure that they have not been answered before.
